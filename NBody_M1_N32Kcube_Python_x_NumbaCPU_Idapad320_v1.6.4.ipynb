# %% [markdown]
# # <center> N-Body gravitacional em Python x Python NumPy x </center>
# # <center> Python Numba CPU x Python Numba CPU // x Python Numba GPU 64 bits </center>
# ## <center> v1.6.4 - 22/11/2018 a 22/02/2019 </center>
# ## <center> $M = 1$ passo, $dt = 0.01$, $N = 32^3 = 32K$ corpos em cubo homogêneo</center>

# %% [markdown]
# ### Autoria da v1.0, v1.3, v1.4, 1.6 : Flávio Manoel Santos Hemerli
# #### Revisão v1.1, v1.2, v1.3.1, v1.4.1, v1.4.6-9, v1.5.0-6, v1.6.2-4 : Roberto Colistete Júnior

# %% [markdown]
# Computador do prof. Roberto Colistete Jr. :
# **Notebook Dell XPS 15** com CPU [**Intel Core i7 2670QM**](https://ark.intel.com/products/53469/Intel-Core-i7-2670QM-Processor-6M-Cache-up-to-3-10-GHz-) 2,2-3,1 GHz 4 cores/8 threads 6MB cache com GPU integrada Intel HD Graphics 3000 & GPU dedicada [**NVidia GeForce GPU GT 540M**](https://www.geforce.com/hardware/notebook-gpus/geforce-gt-540m/specifications) 2GB 96 cores CC2.1.
# Manjaro KDE 18.0.2 64 bits, kernel 4.20.3, gcc 8.2.1, driver NVidia 390.87, CUDA 8.0.
# Anaconda 3 2018-12, Python 3.7.1, NumPy 1.15.4, PyCUDA 2018.1.1 (Python 2.7.15), Numba 0.41.0 com CUDAToolkit 8.0.

# %% [markdown]
# Computador do prof. Roberto Colistete Jr. :
# **Notebook Dell G3 15 3579** com CPU [**Intel Core i7 8750H**](https://ark.intel.com/products/134906/Intel-Core-i7-8750H-Processor-9M-Cache-up-to-4-10-GHz-) Kaby Lake 2,2-4,1 GHz 6 cores/12 threads 9MB cache com GPU integrada Intel UHD Graphics 630 & GPU dedicada [**NVidia GeForce GTX 1050 Ti Mobile**](https://www.nvidia.com/en-us/geforce/products/10series/laptops/) 4GB 768 cores CC6.1.
# Manjaro KDE 18.0.2 64 bits, kernel 4.20.1, gcc 8.2.1, driver NVidia 415.25, CUDA 10.0.
# Anaconda 3 2018-12, Python 3.7.1, NumPy 1.15.4, PyCUDA 2018.1.1 (Python 2.7.15), Numba 0.41.0 com CUDAToolkit 9.2.

# %% [markdown]
# Computador do aluno Flávio Manoel Santos Hemerli:
# **Notebook Lenovo Ideapad 320** com CPU [**Intel Core i5 7200U**](https://ark.intel.com/pt-br/products/95443/Intel-Core-i5-7200U-Processor-3M-Cache-up-to-3-10-GHz-) 2,5-3,1 GHz 2 cores/4 threads 3MB cache com GPU integrada Intel HD Graphics 620. 8GB RAM DDR4 2133MHz Dual Channel.
# Manjaro Deepin 18.0 64 bits. Anaconda 3 2018-12, Python 3.7.1, NumPy 1.15.4, Numba 0.41.0

# %% [markdown]
# -> **Computador na nuvem Google Colab(oratory)** :
# Servidor com CPU [**Intel Xeon** E5-2699 (ou semelhante)](https://ark.intel.com/pt-br/products/81061/Intel-Xeon-Processor-E5-2699-v3-45M-Cache-2-30-GHz-) 2,3-3,6 GHz 18 cores/36 threads 45MB cache & GPU dedicada [**NVidia Tesla K80**](https://www.nvidia.com.br/object/tesla-k80-br.html) 24GB 2x2496 cores CC3.7.
# Acessível via Google Colab : Xeon 2 cores 12-13GB de RAM, K80 com (possivelmente) 2496 cores e 11GB de RAM.
# Ubuntu 18.04.1 64 bits. Python 3.6.7, NumPy 1.14.6, Numba 0.40.1 com CUDA 9.2.

# %% [markdown]
# ### Inicialização

# %%
# !find / -iname 'libdevice'
# !find / -iname 'libnvvm.so'
# Out:
# find: ‘/run/udisks2’: Permissão negada
# find: ‘/run/cups/certs’: Permissão negada
# find: ‘/run/svnserve’: Permissão negada
# find: ‘/run/sudo’: Permissão negada
# find: ‘/run/openvpn-server’: Permissão negada
# find: ‘/run/openvpn-client’: Permissão negada
# find: ‘/run/cryptsetup’: Permissão negada
# find: ‘/run/lock/lvm’: Permissão negada
# find: ‘/run/systemd/unit-root’: Permissão negada
# find: ‘/run/systemd/inaccessible’: Permissão negada
# find: ‘/var/cache/cups’: Permissão negada
# find: ‘/var/cache/ldconfig’: Permissão negada
# find: ‘/var/cache/private’: Permissão negada
# find: ‘/var/spool/cups’: Permissão negada
# find: ‘/var/db/sudo’: Permissão negada
# find: ‘/var/tmp/systemd-private-ec1cd5dfadb249fc9b4b1bf46c033e07-ModemManager.service-pmAfWE’: Permissão negada
# find: ‘/var/tmp/systemd-private-ec1cd5dfadb249fc9b4b1bf46c033e07-systemd-logind.service-9Jl8O1’: Permissão negada
# find: ‘/var/tmp/systemd-private-ec1cd5dfadb249fc9b4b1bf46c033e07-systemd-timesyncd.service-lSI1Io’: Permissão negada
# find: ‘/var/tmp/systemd-private-ec1cd5dfadb249fc9b4b1bf46c033e07-upower.service-GMr2OQ’: Permissão negada
# find: ‘/var/log/private’: Permissão negada
# find: ‘/var/lib/NetworkManager’: Permissão negada
# find: ‘/var/lib/portables’: Permissão negada
# find: ‘/var/lib/private’: Permissão negada
# find: ‘/var/lib/bluetooth’: Permissão negada
# find: ‘/var/lib/samba/private’: Permissão negada
# find: ‘/var/lib/samba/bind-dns’: Permissão negada
# find: ‘/var/lib/udisks2’: Permissão negada
# find: ‘/var/lib/sddm/.config’: Permissão negada
# find: ‘/var/lib/AccountsService/users’: Permissão negada
# find: ‘/var/lib/gssproxy/rcache’: Permissão negada
# find: ‘/var/lib/nfs/sm.bak’: Permissão negada
# find: ‘/var/lib/nfs/sm’: Permissão negada
# find: ‘/var/lib/rpcbind’: Permissão negada
# find: ‘/var/lib/machines’: Permissão negada
# find: ‘/home/lost+found’: Permissão negada
# find: ‘/root’: Permissão negada
# find: ‘/proc/tty/driver’: Permissão negada
# find: ‘/proc/1/task/1/fd’: Permissão negada
# find: ‘/proc/1/task/1/fdinfo’: Permissão negada
# find: ‘/proc/1/task/1/ns’: Permissão negada
# find: ‘/proc/1/fd’: Permissão negada
# find: ‘/proc/1/map_files’: Permissão negada
# find: ‘/proc/1/fdinfo’: Permissão negada
# find: ‘/proc/1/ns’: Permissão negada
# find: ‘/proc/2/task/2/fd’: Permissão negada
# find: ‘/proc/2/task/2/fdinfo’: Permissão negada
# find: ‘/proc/2/task/2/ns’: Permissão negada
# find: ‘/proc/2/fd’: Permissão negada
# find: ‘/proc/2/map_files’: Permissão negada
# find: ‘/proc/2/fdinfo’: Permissão negada
# find: ‘/proc/2/ns’: Permissão negada
# find: ‘/proc/3/task/3/fd’: Permissão negada
# find: ‘/proc/3/task/3/fdinfo’: Permissão negada
# find: ‘/proc/3/task/3/ns’: Permissão negada
# find: ‘/proc/3/fd’: Permissão negada
# find: ‘/proc/3/map_files’: Permissão negada
# find: ‘/proc/3/fdinfo’: Permissão negada
# find: ‘/proc/3/ns’: Permissão negada
# find: ‘/proc/4/task/4/fd’: Permissão negada
# find: ‘/proc/4/task/4/fdinfo’: Permissão negada
# find: ‘/proc/4/task/4/ns’: Permissão negada
# find: ‘/proc/4/fd’: Permissão negada
# find: ‘/proc/4/map_files’: Permissão negada
# find: ‘/proc/4/fdinfo’: Permissão negada
# find: ‘/proc/4/ns’: Permissão negada
# find: ‘/proc/6/task/6/fd’: Permissão negada
# find: ‘/proc/6/task/6/fdinfo’: Permissão negada
# find: ‘/proc/6/task/6/ns’: Permissão negada
# find: ‘/proc/6/fd’: Permissão negada
# find: ‘/proc/6/map_files’: Permissão negada
# find: ‘/proc/6/fdinfo’: Permissão negada
# find: ‘/proc/6/ns’: Permissão negada
# find: ‘/proc/8/task/8/fd’: Permissão negada
# find: ‘/proc/8/task/8/fdinfo’: Permissão negada
# find: ‘/proc/8/task/8/ns’: Permissão negada
# find: ‘/proc/8/fd’: Permissão negada
# find: ‘/proc/8/map_files’: Permissão negada
# find: ‘/proc/8/fdinfo’: Permissão negada
# find: ‘/proc/8/ns’: Permissão negada
# find: ‘/proc/9/task/9/fd’: Permissão negada
# find: ‘/proc/9/task/9/fdinfo’: Permissão negada
# find: ‘/proc/9/task/9/ns’: Permissão negada
# find: ‘/proc/9/fd’: Permissão negada
# find: ‘/proc/9/map_files’: Permissão negada
# find: ‘/proc/9/fdinfo’: Permissão negada
# find: ‘/proc/9/ns’: Permissão negada
# find: ‘/proc/10/task/10/fd’: Permissão negada
# find: ‘/proc/10/task/10/fdinfo’: Permissão negada
# find: ‘/proc/10/task/10/ns’: Permissão negada
# find: ‘/proc/10/fd’: Permissão negada
# find: ‘/proc/10/map_files’: Permissão negada
# find: ‘/proc/10/fdinfo’: Permissão negada
# find: ‘/proc/10/ns’: Permissão negada
# find: ‘/proc/11/task/11/fd’: Permissão negada
# find: ‘/proc/11/task/11/fdinfo’: Permissão negada
# find: ‘/proc/11/task/11/ns’: Permissão negada
# find: ‘/proc/11/fd’: Permissão negada
# find: ‘/proc/11/map_files’: Permissão negada
# find: ‘/proc/11/fdinfo’: Permissão negada
# find: ‘/proc/11/ns’: Permissão negada
# find: ‘/proc/12/task/12/fd’: Permissão negada
# find: ‘/proc/12/task/12/fdinfo’: Permissão negada
# find: ‘/proc/12/task/12/ns’: Permissão negada
# find: ‘/proc/12/fd’: Permissão negada
# find: ‘/proc/12/map_files’: Permissão negada
# find: ‘/proc/12/fdinfo’: Permissão negada
# find: ‘/proc/12/ns’: Permissão negada
# find: ‘/proc/13/task/13/fd’: Permissão negada
# find: ‘/proc/13/task/13/fdinfo’: Permissão negada
# find: ‘/proc/13/task/13/ns’: Permissão negada
# find: ‘/proc/13/fd’: Permissão negada
# find: ‘/proc/13/map_files’: Permissão negada
# find: ‘/proc/13/fdinfo’: Permissão negada
# find: ‘/proc/13/ns’: Permissão negada
# find: ‘/proc/14/task/14/fd’: Permissão negada
# find: ‘/proc/14/task/14/fdinfo’: Permissão negada
# find: ‘/proc/14/task/14/ns’: Permissão negada
# find: ‘/proc/14/fd’: Permissão negada
# find: ‘/proc/14/map_files’: Permissão negada
# find: ‘/proc/14/fdinfo’: Permissão negada
# find: ‘/proc/14/ns’: Permissão negada
# find: ‘/proc/15/task/15/fd’: Permissão negada
# find: ‘/proc/15/task/15/fdinfo’: Permissão negada
# find: ‘/proc/15/task/15/ns’: Permissão negada
# find: ‘/proc/15/fd’: Permissão negada
# find: ‘/proc/15/map_files’: Permissão negada
# find: ‘/proc/15/fdinfo’: Permissão negada
# find: ‘/proc/15/ns’: Permissão negada
# find: ‘/proc/16/task/16/fd’: Permissão negada
# find: ‘/proc/16/task/16/fdinfo’: Permissão negada
# find: ‘/proc/16/task/16/ns’: Permissão negada
# find: ‘/proc/16/fd’: Permissão negada
# find: ‘/proc/16/map_files’: Permissão negada
# find: ‘/proc/16/fdinfo’: Permissão negada
# find: ‘/proc/16/ns’: Permissão negada
# find: ‘/proc/17/task/17/fd’: Permissão negada
# find: ‘/proc/17/task/17/fdinfo’: Permissão negada
# find: ‘/proc/17/task/17/ns’: Permissão negada
# find: ‘/proc/17/fd’: Permissão negada
# find: ‘/proc/17/map_files’: Permissão negada
# find: ‘/proc/17/fdinfo’: Permissão negada
# find: ‘/proc/17/ns’: Permissão negada
# find: ‘/proc/18/task/18/fd’: Permissão negada
# find: ‘/proc/18/task/18/fdinfo’: Permissão negada
# find: ‘/proc/18/task/18/ns’: Permissão negada
# find: ‘/proc/18/fd’: Permissão negada
# find: ‘/proc/18/map_files’: Permissão negada
# find: ‘/proc/18/fdinfo’: Permissão negada
# find: ‘/proc/18/ns’: Permissão negada
# find: ‘/proc/19/task/19/fd’: Permissão negada
# find: ‘/proc/19/task/19/fdinfo’: Permissão negada
# find: ‘/proc/19/task/19/ns’: Permissão negada
# find: ‘/proc/19/fd’: Permissão negada
# find: ‘/proc/19/map_files’: Permissão negada
# find: ‘/proc/19/fdinfo’: Permissão negada
# find: ‘/proc/19/ns’: Permissão negada
# find: ‘/proc/20/task/20/fd’: Permissão negada
# find: ‘/proc/20/task/20/fdinfo’: Permissão negada
# find: ‘/proc/20/task/20/ns’: Permissão negada
# find: ‘/proc/20/fd’: Permissão negada
# find: ‘/proc/20/map_files’: Permissão negada
# find: ‘/proc/20/fdinfo’: Permissão negada
# find: ‘/proc/20/ns’: Permissão negada
# find: ‘/proc/21/task/21/fd’: Permissão negada
# find: ‘/proc/21/task/21/fdinfo’: Permissão negada
# find: ‘/proc/21/task/21/ns’: Permissão negada
# find: ‘/proc/21/fd’: Permissão negada
# find: ‘/proc/21/map_files’: Permissão negada
# find: ‘/proc/21/fdinfo’: Permissão negada
# find: ‘/proc/21/ns’: Permissão negada
# find: ‘/proc/22/task/22/fd’: Permissão negada
# find: ‘/proc/22/task/22/fdinfo’: Permissão negada
# find: ‘/proc/22/task/22/ns’: Permissão negada
# find: ‘/proc/22/fd’: Permissão negada
# find: ‘/proc/22/map_files’: Permissão negada
# find: ‘/proc/22/fdinfo’: Permissão negada
# find: ‘/proc/22/ns’: Permissão negada
# find: ‘/proc/23/task/23/fd’: Permissão negada
# find: ‘/proc/23/task/23/fdinfo’: Permissão negada
# find: ‘/proc/23/task/23/ns’: Permissão negada
# find: ‘/proc/23/fd’: Permissão negada
# find: ‘/proc/23/map_files’: Permissão negada
# find: ‘/proc/23/fdinfo’: Permissão negada
# find: ‘/proc/23/ns’: Permissão negada
# find: ‘/proc/24/task/24/fd’: Permissão negada
# find: ‘/proc/24/task/24/fdinfo’: Permissão negada
# find: ‘/proc/24/task/24/ns’: Permissão negada
# find: ‘/proc/24/fd’: Permissão negada
# find: ‘/proc/24/map_files’: Permissão negada
# find: ‘/proc/24/fdinfo’: Permissão negada
# find: ‘/proc/24/ns’: Permissão negada
# find: ‘/proc/25/task/25/fd’: Permissão negada
# find: ‘/proc/25/task/25/fdinfo’: Permissão negada
# find: ‘/proc/25/task/25/ns’: Permissão negada
# find: ‘/proc/25/fd’: Permissão negada
# find: ‘/proc/25/map_files’: Permissão negada
# find: ‘/proc/25/fdinfo’: Permissão negada
# find: ‘/proc/25/ns’: Permissão negada
# find: ‘/proc/26/task/26/fd’: Permissão negada
# find: ‘/proc/26/task/26/fdinfo’: Permissão negada
# find: ‘/proc/26/task/26/ns’: Permissão negada
# find: ‘/proc/26/fd’: Permissão negada
# find: ‘/proc/26/map_files’: Permissão negada
# find: ‘/proc/26/fdinfo’: Permissão negada
# find: ‘/proc/26/ns’: Permissão negada
# find: ‘/proc/27/task/27/fd’: Permissão negada
# find: ‘/proc/27/task/27/fdinfo’: Permissão negada
# find: ‘/proc/27/task/27/ns’: Permissão negada
# find: ‘/proc/27/fd’: Permissão negada
# find: ‘/proc/27/map_files’: Permissão negada
# find: ‘/proc/27/fdinfo’: Permissão negada
# find: ‘/proc/27/ns’: Permissão negada
# find: ‘/proc/28/task/28/fd’: Permissão negada
# find: ‘/proc/28/task/28/fdinfo’: Permissão negada
# find: ‘/proc/28/task/28/ns’: Permissão negada
# find: ‘/proc/28/fd’: Permissão negada
# find: ‘/proc/28/map_files’: Permissão negada
# find: ‘/proc/28/fdinfo’: Permissão negada
# find: ‘/proc/28/ns’: Permissão negada
# find: ‘/proc/30/task/30/fd’: Permissão negada
# find: ‘/proc/30/task/30/fdinfo’: Permissão negada
# find: ‘/proc/30/task/30/ns’: Permissão negada
# find: ‘/proc/30/fd’: Permissão negada
# find: ‘/proc/30/map_files’: Permissão negada
# find: ‘/proc/30/fdinfo’: Permissão negada
# find: ‘/proc/30/ns’: Permissão negada
# find: ‘/proc/31/task/31/fd’: Permissão negada
# find: ‘/proc/31/task/31/fdinfo’: Permissão negada
# find: ‘/proc/31/task/31/ns’: Permissão negada
# find: ‘/proc/31/fd’: Permissão negada
# find: ‘/proc/31/map_files’: Permissão negada
# find: ‘/proc/31/fdinfo’: Permissão negada
# find: ‘/proc/31/ns’: Permissão negada
# find: ‘/proc/32/task/32/fd’: Permissão negada
# find: ‘/proc/32/task/32/fdinfo’: Permissão negada
# find: ‘/proc/32/task/32/ns’: Permissão negada
# find: ‘/proc/32/fd’: Permissão negada
# find: ‘/proc/32/map_files’: Permissão negada
# find: ‘/proc/32/fdinfo’: Permissão negada
# find: ‘/proc/32/ns’: Permissão negada
# find: ‘/proc/33/task/33/fd’: Permissão negada
# find: ‘/proc/33/task/33/fdinfo’: Permissão negada
# find: ‘/proc/33/task/33/ns’: Permissão negada
# find: ‘/proc/33/fd’: Permissão negada
# find: ‘/proc/33/map_files’: Permissão negada
# find: ‘/proc/33/fdinfo’: Permissão negada
# find: ‘/proc/33/ns’: Permissão negada
# find: ‘/proc/34/task/34/fd’: Permissão negada
# find: ‘/proc/34/task/34/fdinfo’: Permissão negada
# find: ‘/proc/34/task/34/ns’: Permissão negada
# find: ‘/proc/34/fd’: Permissão negada
# find: ‘/proc/34/map_files’: Permissão negada
# find: ‘/proc/34/fdinfo’: Permissão negada
# find: ‘/proc/34/ns’: Permissão negada
# find: ‘/proc/35/task/35/fd’: Permissão negada
# find: ‘/proc/35/task/35/fdinfo’: Permissão negada
# find: ‘/proc/35/task/35/ns’: Permissão negada
# find: ‘/proc/35/fd’: Permissão negada
# find: ‘/proc/35/map_files’: Permissão negada
# find: ‘/proc/35/fdinfo’: Permissão negada
# find: ‘/proc/35/ns’: Permissão negada
# find: ‘/proc/37/task/37/fd’: Permissão negada
# find: ‘/proc/37/task/37/fdinfo’: Permissão negada
# find: ‘/proc/37/task/37/ns’: Permissão negada
# find: ‘/proc/37/fd’: Permissão negada
# find: ‘/proc/37/map_files’: Permissão negada
# find: ‘/proc/37/fdinfo’: Permissão negada
# find: ‘/proc/37/ns’: Permissão negada
# find: ‘/proc/38/task/38/fd’: Permissão negada
# find: ‘/proc/38/task/38/fdinfo’: Permissão negada
# find: ‘/proc/38/task/38/ns’: Permissão negada
# find: ‘/proc/38/fd’: Permissão negada
# find: ‘/proc/38/map_files’: Permissão negada
# find: ‘/proc/38/fdinfo’: Permissão negada
# find: ‘/proc/38/ns’: Permissão negada
# find: ‘/proc/39/task/39/fd’: Permissão negada
# find: ‘/proc/39/task/39/fdinfo’: Permissão negada
# find: ‘/proc/39/task/39/ns’: Permissão negada
# find: ‘/proc/39/fd’: Permissão negada
# find: ‘/proc/39/map_files’: Permissão negada
# find: ‘/proc/39/fdinfo’: Permissão negada
# find: ‘/proc/39/ns’: Permissão negada
# find: ‘/proc/40/task/40/fd’: Permissão negada
# find: ‘/proc/40/task/40/fdinfo’: Permissão negada
# find: ‘/proc/40/task/40/ns’: Permissão negada
# find: ‘/proc/40/fd’: Permissão negada
# find: ‘/proc/40/map_files’: Permissão negada
# find: ‘/proc/40/fdinfo’: Permissão negada
# find: ‘/proc/40/ns’: Permissão negada
# find: ‘/proc/41/task/41/fd’: Permissão negada
# find: ‘/proc/41/task/41/fdinfo’: Permissão negada
# find: ‘/proc/41/task/41/ns’: Permissão negada
# find: ‘/proc/41/fd’: Permissão negada
# find: ‘/proc/41/map_files’: Permissão negada
# find: ‘/proc/41/fdinfo’: Permissão negada
# find: ‘/proc/41/ns’: Permissão negada
# find: ‘/proc/42/task/42/fd’: Permissão negada
# find: ‘/proc/42/task/42/fdinfo’: Permissão negada
# find: ‘/proc/42/task/42/ns’: Permissão negada
# find: ‘/proc/42/fd’: Permissão negada
# find: ‘/proc/42/map_files’: Permissão negada
# find: ‘/proc/42/fdinfo’: Permissão negada
# find: ‘/proc/42/ns’: Permissão negada
# find: ‘/proc/43/task/43/fd’: Permissão negada
# find: ‘/proc/43/task/43/fdinfo’: Permissão negada
# find: ‘/proc/43/task/43/ns’: Permissão negada
# find: ‘/proc/43/fd’: Permissão negada
# find: ‘/proc/43/map_files’: Permissão negada
# find: ‘/proc/43/fdinfo’: Permissão negada
# find: ‘/proc/43/ns’: Permissão negada
# find: ‘/proc/44/task/44/fd’: Permissão negada
# find: ‘/proc/44/task/44/fdinfo’: Permissão negada
# find: ‘/proc/44/task/44/ns’: Permissão negada
# find: ‘/proc/44/fd’: Permissão negada
# find: ‘/proc/44/map_files’: Permissão negada
# find: ‘/proc/44/fdinfo’: Permissão negada
# find: ‘/proc/44/ns’: Permissão negada
# find: ‘/proc/45/task/45/fd’: Permissão negada
# find: ‘/proc/45/task/45/fdinfo’: Permissão negada
# find: ‘/proc/45/task/45/ns’: Permissão negada
# find: ‘/proc/45/fd’: Permissão negada
# find: ‘/proc/45/map_files’: Permissão negada
# find: ‘/proc/45/fdinfo’: Permissão negada
# find: ‘/proc/45/ns’: Permissão negada
# find: ‘/proc/46/task/46/fd’: Permissão negada
# find: ‘/proc/46/task/46/fdinfo’: Permissão negada
# find: ‘/proc/46/task/46/ns’: Permissão negada
# find: ‘/proc/46/fd’: Permissão negada
# find: ‘/proc/46/map_files’: Permissão negada
# find: ‘/proc/46/fdinfo’: Permissão negada
# find: ‘/proc/46/ns’: Permissão negada
# find: ‘/proc/47/task/47/fd’: Permissão negada
# find: ‘/proc/47/task/47/fdinfo’: Permissão negada
# find: ‘/proc/47/task/47/ns’: Permissão negada
# find: ‘/proc/47/fd’: Permissão negada
# find: ‘/proc/47/map_files’: Permissão negada
# find: ‘/proc/47/fdinfo’: Permissão negada
# find: ‘/proc/47/ns’: Permissão negada
# find: ‘/proc/48/task/48/fd’: Permissão negada
# find: ‘/proc/48/task/48/fdinfo’: Permissão negada
# find: ‘/proc/48/task/48/ns’: Permissão negada
# find: ‘/proc/48/fd’: Permissão negada
# find: ‘/proc/48/map_files’: Permissão negada
# find: ‘/proc/48/fdinfo’: Permissão negada
# find: ‘/proc/48/ns’: Permissão negada
# find: ‘/proc/49/task/49/fd’: Permissão negada
# find: ‘/proc/49/task/49/fdinfo’: Permissão negada
# find: ‘/proc/49/task/49/ns’: Permissão negada
# find: ‘/proc/49/fd’: Permissão negada
# find: ‘/proc/49/map_files’: Permissão negada
# find: ‘/proc/49/fdinfo’: Permissão negada
# find: ‘/proc/49/ns’: Permissão negada
# find: ‘/proc/50/task/50/fd’: Permissão negada
# find: ‘/proc/50/task/50/fdinfo’: Permissão negada
# find: ‘/proc/50/task/50/ns’: Permissão negada
# find: ‘/proc/50/fd’: Permissão negada
# find: ‘/proc/50/map_files’: Permissão negada
# find: ‘/proc/50/fdinfo’: Permissão negada
# find: ‘/proc/50/ns’: Permissão negada
# find: ‘/proc/51/task/51/fd’: Permissão negada
# find: ‘/proc/51/task/51/fdinfo’: Permissão negada
# find: ‘/proc/51/task/51/ns’: Permissão negada
# find: ‘/proc/51/fd’: Permissão negada
# find: ‘/proc/51/map_files’: Permissão negada
# find: ‘/proc/51/fdinfo’: Permissão negada
# find: ‘/proc/51/ns’: Permissão negada
# find: ‘/proc/52/task/52/fd’: Permissão negada
# find: ‘/proc/52/task/52/fdinfo’: Permissão negada
# find: ‘/proc/52/task/52/ns’: Permissão negada
# find: ‘/proc/52/fd’: Permissão negada
# find: ‘/proc/52/map_files’: Permissão negada
# find: ‘/proc/52/fdinfo’: Permissão negada
# find: ‘/proc/52/ns’: Permissão negada
# find: ‘/proc/54/task/54/fd’: Permissão negada
# find: ‘/proc/54/task/54/fdinfo’: Permissão negada
# find: ‘/proc/54/task/54/ns’: Permissão negada
# find: ‘/proc/54/fd’: Permissão negada
# find: ‘/proc/54/map_files’: Permissão negada
# find: ‘/proc/54/fdinfo’: Permissão negada
# find: ‘/proc/54/ns’: Permissão negada
# find: ‘/proc/56/task/56/fd’: Permissão negada
# find: ‘/proc/56/task/56/fdinfo’: Permissão negada
# find: ‘/proc/56/task/56/ns’: Permissão negada
# find: ‘/proc/56/fd’: Permissão negada
# find: ‘/proc/56/map_files’: Permissão negada
# find: ‘/proc/56/fdinfo’: Permissão negada
# find: ‘/proc/56/ns’: Permissão negada
# find: ‘/proc/57/task/57/fd’: Permissão negada
# find: ‘/proc/57/task/57/fdinfo’: Permissão negada
# find: ‘/proc/57/task/57/ns’: Permissão negada
# find: ‘/proc/57/fd’: Permissão negada
# find: ‘/proc/57/map_files’: Permissão negada
# find: ‘/proc/57/fdinfo’: Permissão negada
# find: ‘/proc/57/ns’: Permissão negada
# find: ‘/proc/58/task/58/fd’: Permissão negada
# find: ‘/proc/58/task/58/fdinfo’: Permissão negada
# find: ‘/proc/58/task/58/ns’: Permissão negada
# find: ‘/proc/58/fd’: Permissão negada
# find: ‘/proc/58/map_files’: Permissão negada
# find: ‘/proc/58/fdinfo’: Permissão negada
# find: ‘/proc/58/ns’: Permissão negada
# find: ‘/proc/59/task/59/fd’: Permissão negada
# find: ‘/proc/59/task/59/fdinfo’: Permissão negada
# find: ‘/proc/59/task/59/ns’: Permissão negada
# find: ‘/proc/59/fd’: Permissão negada
# find: ‘/proc/59/map_files’: Permissão negada
# find: ‘/proc/59/fdinfo’: Permissão negada
# find: ‘/proc/59/ns’: Permissão negada
# find: ‘/proc/148/task/148/fd’: Permissão negada
# find: ‘/proc/148/task/148/fdinfo’: Permissão negada
# find: ‘/proc/148/task/148/ns’: Permissão negada
# find: ‘/proc/148/fd’: Permissão negada
# find: ‘/proc/148/map_files’: Permissão negada
# find: ‘/proc/148/fdinfo’: Permissão negada
# find: ‘/proc/148/ns’: Permissão negada
# find: ‘/proc/149/task/149/fd’: Permissão negada
# find: ‘/proc/149/task/149/fdinfo’: Permissão negada
# find: ‘/proc/149/task/149/ns’: Permissão negada
# find: ‘/proc/149/fd’: Permissão negada
# find: ‘/proc/149/map_files’: Permissão negada
# find: ‘/proc/149/fdinfo’: Permissão negada
# find: ‘/proc/149/ns’: Permissão negada
# find: ‘/proc/150/task/150/fd’: Permissão negada
# find: ‘/proc/150/task/150/fdinfo’: Permissão negada
# find: ‘/proc/150/task/150/ns’: Permissão negada
# find: ‘/proc/150/fd’: Permissão negada
# find: ‘/proc/150/map_files’: Permissão negada
# find: ‘/proc/150/fdinfo’: Permissão negada
# find: ‘/proc/150/ns’: Permissão negada
# find: ‘/proc/151/task/151/fd’: Permissão negada
# find: ‘/proc/151/task/151/fdinfo’: Permissão negada
# find: ‘/proc/151/task/151/ns’: Permissão negada
# find: ‘/proc/151/fd’: Permissão negada
# find: ‘/proc/151/map_files’: Permissão negada
# find: ‘/proc/151/fdinfo’: Permissão negada
# find: ‘/proc/151/ns’: Permissão negada
# find: ‘/proc/152/task/152/fd’: Permissão negada
# find: ‘/proc/152/task/152/fdinfo’: Permissão negada
# find: ‘/proc/152/task/152/ns’: Permissão negada
# find: ‘/proc/152/fd’: Permissão negada
# find: ‘/proc/152/map_files’: Permissão negada
# find: ‘/proc/152/fdinfo’: Permissão negada
# find: ‘/proc/152/ns’: Permissão negada
# find: ‘/proc/153/task/153/fd’: Permissão negada
# find: ‘/proc/153/task/153/fdinfo’: Permissão negada
# find: ‘/proc/153/task/153/ns’: Permissão negada
# find: ‘/proc/153/fd’: Permissão negada
# find: ‘/proc/153/map_files’: Permissão negada
# find: ‘/proc/153/fdinfo’: Permissão negada
# find: ‘/proc/153/ns’: Permissão negada
# find: ‘/proc/164/task/164/fd’: Permissão negada
# find: ‘/proc/164/task/164/fdinfo’: Permissão negada
# find: ‘/proc/164/task/164/ns’: Permissão negada
# find: ‘/proc/164/fd’: Permissão negada
# find: ‘/proc/164/map_files’: Permissão negada
# find: ‘/proc/164/fdinfo’: Permissão negada
# find: ‘/proc/164/ns’: Permissão negada
# find: ‘/proc/180/task/180/fd’: Permissão negada
# find: ‘/proc/180/task/180/fdinfo’: Permissão negada
# find: ‘/proc/180/task/180/ns’: Permissão negada
# find: ‘/proc/180/fd’: Permissão negada
# find: ‘/proc/180/map_files’: Permissão negada
# find: ‘/proc/180/fdinfo’: Permissão negada
# find: ‘/proc/180/ns’: Permissão negada
# find: ‘/proc/207/task/207/fd’: Permissão negada
# find: ‘/proc/207/task/207/fdinfo’: Permissão negada
# find: ‘/proc/207/task/207/ns’: Permissão negada
# find: ‘/proc/207/fd’: Permissão negada
# find: ‘/proc/207/map_files’: Permissão negada
# find: ‘/proc/207/fdinfo’: Permissão negada
# find: ‘/proc/207/ns’: Permissão negada
# find: ‘/proc/208/task/208/fd’: Permissão negada
# find: ‘/proc/208/task/208/fdinfo’: Permissão negada
# find: ‘/proc/208/task/208/ns’: Permissão negada
# find: ‘/proc/208/fd’: Permissão negada
# find: ‘/proc/208/map_files’: Permissão negada
# find: ‘/proc/208/fdinfo’: Permissão negada
# find: ‘/proc/208/ns’: Permissão negada
# find: ‘/proc/209/task/209/fd’: Permissão negada
# find: ‘/proc/209/task/209/fdinfo’: Permissão negada
# find: ‘/proc/209/task/209/ns’: Permissão negada
# find: ‘/proc/209/fd’: Permissão negada
# find: ‘/proc/209/map_files’: Permissão negada
# find: ‘/proc/209/fdinfo’: Permissão negada
# find: ‘/proc/209/ns’: Permissão negada
# find: ‘/proc/210/task/210/fd’: Permissão negada
# find: ‘/proc/210/task/210/fdinfo’: Permissão negada
# find: ‘/proc/210/task/210/ns’: Permissão negada
# find: ‘/proc/210/fd’: Permissão negada
# find: ‘/proc/210/map_files’: Permissão negada
# find: ‘/proc/210/fdinfo’: Permissão negada
# find: ‘/proc/210/ns’: Permissão negada
# find: ‘/proc/211/task/211/fd’: Permissão negada
# find: ‘/proc/211/task/211/fdinfo’: Permissão negada
# find: ‘/proc/211/task/211/ns’: Permissão negada
# find: ‘/proc/211/fd’: Permissão negada
# find: ‘/proc/211/map_files’: Permissão negada
# find: ‘/proc/211/fdinfo’: Permissão negada
# find: ‘/proc/211/ns’: Permissão negada
# find: ‘/proc/215/task/215/fd’: Permissão negada
# find: ‘/proc/215/task/215/fdinfo’: Permissão negada
# find: ‘/proc/215/task/215/ns’: Permissão negada
# find: ‘/proc/215/fd’: Permissão negada
# find: ‘/proc/215/map_files’: Permissão negada
# find: ‘/proc/215/fdinfo’: Permissão negada
# find: ‘/proc/215/ns’: Permissão negada
# find: ‘/proc/216/task/216/fd’: Permissão negada
# find: ‘/proc/216/task/216/fdinfo’: Permissão negada
# find: ‘/proc/216/task/216/ns’: Permissão negada
# find: ‘/proc/216/fd’: Permissão negada
# find: ‘/proc/216/map_files’: Permissão negada
# find: ‘/proc/216/fdinfo’: Permissão negada
# find: ‘/proc/216/ns’: Permissão negada
# find: ‘/proc/230/task/230/fd’: Permissão negada
# find: ‘/proc/230/task/230/fdinfo’: Permissão negada
# find: ‘/proc/230/task/230/ns’: Permissão negada
# find: ‘/proc/230/fd’: Permissão negada
# find: ‘/proc/230/map_files’: Permissão negada
# find: ‘/proc/230/fdinfo’: Permissão negada
# find: ‘/proc/230/ns’: Permissão negada
# find: ‘/proc/231/task/231/fd’: Permissão negada
# find: ‘/proc/231/task/231/fdinfo’: Permissão negada
# find: ‘/proc/231/task/231/ns’: Permissão negada
# find: ‘/proc/231/fd’: Permissão negada
# find: ‘/proc/231/map_files’: Permissão negada
# find: ‘/proc/231/fdinfo’: Permissão negada
# find: ‘/proc/231/ns’: Permissão negada
# find: ‘/proc/232/task/232/fd’: Permissão negada
# find: ‘/proc/232/task/232/fdinfo’: Permissão negada
# find: ‘/proc/232/task/232/ns’: Permissão negada
# find: ‘/proc/232/fd’: Permissão negada
# find: ‘/proc/232/map_files’: Permissão negada
# find: ‘/proc/232/fdinfo’: Permissão negada
# find: ‘/proc/232/ns’: Permissão negada
# find: ‘/proc/237/task/237/fd’: Permissão negada
# find: ‘/proc/237/task/237/fdinfo’: Permissão negada
# find: ‘/proc/237/task/237/ns’: Permissão negada
# find: ‘/proc/237/fd’: Permissão negada
# find: ‘/proc/237/map_files’: Permissão negada
# find: ‘/proc/237/fdinfo’: Permissão negada
# find: ‘/proc/237/ns’: Permissão negada
# find: ‘/proc/264/task/264/fd’: Permissão negada
# find: ‘/proc/264/task/264/fdinfo’: Permissão negada
# find: ‘/proc/264/task/264/ns’: Permissão negada
# find: ‘/proc/264/fd’: Permissão negada
# find: ‘/proc/264/map_files’: Permissão negada
# find: ‘/proc/264/fdinfo’: Permissão negada
# find: ‘/proc/264/ns’: Permissão negada
# find: ‘/proc/274/task/274/fd’: Permissão negada
# find: ‘/proc/274/task/274/fdinfo’: Permissão negada
# find: ‘/proc/274/task/274/ns’: Permissão negada
# find: ‘/proc/274/fd’: Permissão negada
# find: ‘/proc/274/map_files’: Permissão negada
# find: ‘/proc/274/fdinfo’: Permissão negada
# find: ‘/proc/274/ns’: Permissão negada
# find: ‘/proc/275/task/275/fd’: Permissão negada
# find: ‘/proc/275/task/275/fdinfo’: Permissão negada
# find: ‘/proc/275/task/275/ns’: Permissão negada
# find: ‘/proc/275/fd’: Permissão negada
# find: ‘/proc/275/map_files’: Permissão negada
# find: ‘/proc/275/fdinfo’: Permissão negada
# find: ‘/proc/275/ns’: Permissão negada
# find: ‘/proc/278/task/278/fd’: Permissão negada
# find: ‘/proc/278/task/278/fdinfo’: Permissão negada
# find: ‘/proc/278/task/278/ns’: Permissão negada
# find: ‘/proc/278/fd’: Permissão negada
# find: ‘/proc/278/map_files’: Permissão negada
# find: ‘/proc/278/fdinfo’: Permissão negada
# find: ‘/proc/278/ns’: Permissão negada
# find: ‘/proc/320/task/320/fd’: Permissão negada
# find: ‘/proc/320/task/320/fdinfo’: Permissão negada
# find: ‘/proc/320/task/320/ns’: Permissão negada
# find: ‘/proc/320/fd’: Permissão negada
# find: ‘/proc/320/map_files’: Permissão negada
# find: ‘/proc/320/fdinfo’: Permissão negada
# find: ‘/proc/320/ns’: Permissão negada
# find: ‘/proc/340/task/340/fd’: Permissão negada
# find: ‘/proc/340/task/340/fdinfo’: Permissão negada
# find: ‘/proc/340/task/340/ns’: Permissão negada
# find: ‘/proc/340/fd’: Permissão negada
# find: ‘/proc/340/map_files’: Permissão negada
# find: ‘/proc/340/fdinfo’: Permissão negada
# find: ‘/proc/340/ns’: Permissão negada
# find: ‘/proc/342/task/342/fd’: Permissão negada
# find: ‘/proc/342/task/342/fdinfo’: Permissão negada
# find: ‘/proc/342/task/342/ns’: Permissão negada
# find: ‘/proc/342/fd’: Permissão negada
# find: ‘/proc/342/map_files’: Permissão negada
# find: ‘/proc/342/fdinfo’: Permissão negada
# find: ‘/proc/342/ns’: Permissão negada
# find: ‘/proc/351/task/351/fd’: Permissão negada
# find: ‘/proc/351/task/351/fdinfo’: Permissão negada
# find: ‘/proc/351/task/351/ns’: Permissão negada
# find: ‘/proc/351/fd’: Permissão negada
# find: ‘/proc/351/map_files’: Permissão negada
# find: ‘/proc/351/fdinfo’: Permissão negada
# find: ‘/proc/351/ns’: Permissão negada
# find: ‘/proc/399/task/399/fd’: Permissão negada
# find: ‘/proc/399/task/399/fdinfo’: Permissão negada
# find: ‘/proc/399/task/399/ns’: Permissão negada
# find: ‘/proc/399/fd’: Permissão negada
# find: ‘/proc/399/map_files’: Permissão negada
# find: ‘/proc/399/fdinfo’: Permissão negada
# find: ‘/proc/399/ns’: Permissão negada
# find: ‘/proc/400/task/400/fd’: Permissão negada
# find: ‘/proc/400/task/400/fdinfo’: Permissão negada
# find: ‘/proc/400/task/400/ns’: Permissão negada
# find: ‘/proc/400/fd’: Permissão negada
# find: ‘/proc/400/map_files’: Permissão negada
# find: ‘/proc/400/fdinfo’: Permissão negada
# find: ‘/proc/400/ns’: Permissão negada
# find: ‘/proc/405/task/405/fd’: Permissão negada
# find: ‘/proc/405/task/405/fdinfo’: Permissão negada
# find: ‘/proc/405/task/405/ns’: Permissão negada
# find: ‘/proc/405/fd’: Permissão negada
# find: ‘/proc/405/map_files’: Permissão negada
# find: ‘/proc/405/fdinfo’: Permissão negada
# find: ‘/proc/405/ns’: Permissão negada
# find: ‘/proc/411/task/411/fd’: Permissão negada
# find: ‘/proc/411/task/411/fdinfo’: Permissão negada
# find: ‘/proc/411/task/411/ns’: Permissão negada
# find: ‘/proc/411/fd’: Permissão negada
# find: ‘/proc/411/map_files’: Permissão negada
# find: ‘/proc/411/fdinfo’: Permissão negada
# find: ‘/proc/411/ns’: Permissão negada
# find: ‘/proc/426/task/426/fd’: Permissão negada
# find: ‘/proc/426/task/426/fdinfo’: Permissão negada
# find: ‘/proc/426/task/426/ns’: Permissão negada
# find: ‘/proc/426/fd’: Permissão negada
# find: ‘/proc/426/map_files’: Permissão negada
# find: ‘/proc/426/fdinfo’: Permissão negada
# find: ‘/proc/426/ns’: Permissão negada
# find: ‘/proc/549/task/549/fd’: Permissão negada
# find: ‘/proc/549/task/549/fdinfo’: Permissão negada
# find: ‘/proc/549/task/549/ns’: Permissão negada
# find: ‘/proc/549/fd’: Permissão negada
# find: ‘/proc/549/map_files’: Permissão negada
# find: ‘/proc/549/fdinfo’: Permissão negada
# find: ‘/proc/549/ns’: Permissão negada
# find: ‘/proc/550/task/550/fd’: Permissão negada
# find: ‘/proc/550/task/550/fdinfo’: Permissão negada
# find: ‘/proc/550/task/550/ns’: Permissão negada
# find: ‘/proc/550/fd’: Permissão negada
# find: ‘/proc/550/map_files’: Permissão negada
# find: ‘/proc/550/fdinfo’: Permissão negada
# find: ‘/proc/550/ns’: Permissão negada
# find: ‘/proc/553/task/553/fd’: Permissão negada
# find: ‘/proc/553/task/553/fdinfo’: Permissão negada
# find: ‘/proc/553/task/553/ns’: Permissão negada
# find: ‘/proc/553/task/556/fd’: Permissão negada
# find: ‘/proc/553/task/556/fdinfo’: Permissão negada
# find: ‘/proc/553/task/556/ns’: Permissão negada
# find: ‘/proc/553/fd’: Permissão negada
# find: ‘/proc/553/map_files’: Permissão negada
# find: ‘/proc/553/fdinfo’: Permissão negada
# find: ‘/proc/553/ns’: Permissão negada
# find: ‘/proc/559/task/559/fd’: Permissão negada
# find: ‘/proc/559/task/559/fdinfo’: Permissão negada
# find: ‘/proc/559/task/559/ns’: Permissão negada
# find: ‘/proc/559/fd’: Permissão negada
# find: ‘/proc/559/map_files’: Permissão negada
# find: ‘/proc/559/fdinfo’: Permissão negada
# find: ‘/proc/559/ns’: Permissão negada
# find: ‘/proc/560/task/560/fd’: Permissão negada
# find: ‘/proc/560/task/560/fdinfo’: Permissão negada
# find: ‘/proc/560/task/560/ns’: Permissão negada
# find: ‘/proc/560/task/566/fd’: Permissão negada
# find: ‘/proc/560/task/566/fdinfo’: Permissão negada
# find: ‘/proc/560/task/566/ns’: Permissão negada
# find: ‘/proc/560/task/569/fd’: Permissão negada
# find: ‘/proc/560/task/569/fdinfo’: Permissão negada
# find: ‘/proc/560/task/569/ns’: Permissão negada
# find: ‘/proc/560/fd’: Permissão negada
# find: ‘/proc/560/map_files’: Permissão negada
# find: ‘/proc/560/fdinfo’: Permissão negada
# find: ‘/proc/560/ns’: Permissão negada
# find: ‘/proc/561/task/561/fd’: Permissão negada
# find: ‘/proc/561/task/561/fdinfo’: Permissão negada
# find: ‘/proc/561/task/561/ns’: Permissão negada
# find: ‘/proc/561/fd’: Permissão negada
# find: ‘/proc/561/map_files’: Permissão negada
# find: ‘/proc/561/fdinfo’: Permissão negada
# find: ‘/proc/561/ns’: Permissão negada
# find: ‘/proc/562/task/562/fd’: Permissão negada
# find: ‘/proc/562/task/562/fdinfo’: Permissão negada
# find: ‘/proc/562/task/562/ns’: Permissão negada
# find: ‘/proc/562/fd’: Permissão negada
# find: ‘/proc/562/map_files’: Permissão negada
# find: ‘/proc/562/fdinfo’: Permissão negada
# find: ‘/proc/562/ns’: Permissão negada
# find: ‘/proc/563/task/563/fd’: Permissão negada
# find: ‘/proc/563/task/563/fdinfo’: Permissão negada
# find: ‘/proc/563/task/563/ns’: Permissão negada
# find: ‘/proc/563/fd’: Permissão negada
# find: ‘/proc/563/map_files’: Permissão negada
# find: ‘/proc/563/fdinfo’: Permissão negada
# find: ‘/proc/563/ns’: Permissão negada
# find: ‘/proc/564/task/564/fd’: Permissão negada
# find: ‘/proc/564/task/564/fdinfo’: Permissão negada
# find: ‘/proc/564/task/564/ns’: Permissão negada
# find: ‘/proc/564/fd’: Permissão negada
# find: ‘/proc/564/map_files’: Permissão negada
# find: ‘/proc/564/fdinfo’: Permissão negada
# find: ‘/proc/564/ns’: Permissão negada
# find: ‘/proc/565/task/565/fd’: Permissão negada
# find: ‘/proc/565/task/565/fdinfo’: Permissão negada
# find: ‘/proc/565/task/565/ns’: Permissão negada
# find: ‘/proc/565/task/573/fd’: Permissão negada
# find: ‘/proc/565/task/573/fdinfo’: Permissão negada
# find: ‘/proc/565/task/573/ns’: Permissão negada
# find: ‘/proc/565/task/576/fd’: Permissão negada
# find: ‘/proc/565/task/576/fdinfo’: Permissão negada
# find: ‘/proc/565/task/576/ns’: Permissão negada
# find: ‘/proc/565/fd’: Permissão negada
# find: ‘/proc/565/map_files’: Permissão negada
# find: ‘/proc/565/fdinfo’: Permissão negada
# find: ‘/proc/565/ns’: Permissão negada
# find: ‘/proc/570/task/570/fd’: Permissão negada
# find: ‘/proc/570/task/570/fdinfo’: Permissão negada
# find: ‘/proc/570/task/570/ns’: Permissão negada
# find: ‘/proc/570/fd’: Permissão negada
# find: ‘/proc/570/map_files’: Permissão negada
# find: ‘/proc/570/fdinfo’: Permissão negada
# find: ‘/proc/570/ns’: Permissão negada
# find: ‘/proc/572/task/572/fd’: Permissão negada
# find: ‘/proc/572/task/572/fdinfo’: Permissão negada
# find: ‘/proc/572/task/572/ns’: Permissão negada
# find: ‘/proc/572/task/580/fd’: Permissão negada
# find: ‘/proc/572/task/580/fdinfo’: Permissão negada
# find: ‘/proc/572/task/580/ns’: Permissão negada
# find: ‘/proc/572/task/581/fd’: Permissão negada
# find: ‘/proc/572/task/581/fdinfo’: Permissão negada
# find: ‘/proc/572/task/581/ns’: Permissão negada
# find: ‘/proc/572/task/583/fd’: Permissão negada
# find: ‘/proc/572/task/583/fdinfo’: Permissão negada
# find: ‘/proc/572/task/583/ns’: Permissão negada
# find: ‘/proc/572/task/584/fd’: Permissão negada
# find: ‘/proc/572/task/584/fdinfo’: Permissão negada
# find: ‘/proc/572/task/584/ns’: Permissão negada
# find: ‘/proc/572/task/585/fd’: Permissão negada
# find: ‘/proc/572/task/585/fdinfo’: Permissão negada
# find: ‘/proc/572/task/585/ns’: Permissão negada
# find: ‘/proc/572/task/586/fd’: Permissão negada
# find: ‘/proc/572/task/586/fdinfo’: Permissão negada
# find: ‘/proc/572/task/586/ns’: Permissão negada
# find: ‘/proc/572/task/589/fd’: Permissão negada
# find: ‘/proc/572/task/589/fdinfo’: Permissão negada
# find: ‘/proc/572/task/589/ns’: Permissão negada
# find: ‘/proc/572/fd’: Permissão negada
# find: ‘/proc/572/map_files’: Permissão negada
# find: ‘/proc/572/fdinfo’: Permissão negada
# find: ‘/proc/572/ns’: Permissão negada
# find: ‘/proc/578/task/578/fd’: Permissão negada
# find: ‘/proc/578/task/578/fdinfo’: Permissão negada
# find: ‘/proc/578/task/578/ns’: Permissão negada
# find: ‘/proc/578/task/592/fd’: Permissão negada
# find: ‘/proc/578/task/592/fdinfo’: Permissão negada
# find: ‘/proc/578/task/592/ns’: Permissão negada
# find: ‘/proc/578/fd’: Permissão negada
# find: ‘/proc/578/map_files’: Permissão negada
# find: ‘/proc/578/fdinfo’: Permissão negada
# find: ‘/proc/578/ns’: Permissão negada
# find: ‘/proc/593/task/593/fd’: Permissão negada
# find: ‘/proc/593/task/593/fdinfo’: Permissão negada
# find: ‘/proc/593/task/593/ns’: Permissão negada
# find: ‘/proc/593/task/725/fd’: Permissão negada
# find: ‘/proc/593/task/725/fdinfo’: Permissão negada
# find: ‘/proc/593/task/725/ns’: Permissão negada
# find: ‘/proc/593/task/726/fd’: Permissão negada
# find: ‘/proc/593/task/726/fdinfo’: Permissão negada
# find: ‘/proc/593/task/726/ns’: Permissão negada
# find: ‘/proc/593/fd’: Permissão negada
# find: ‘/proc/593/map_files’: Permissão negada
# find: ‘/proc/593/fdinfo’: Permissão negada
# find: ‘/proc/593/ns’: Permissão negada
# find: ‘/proc/661/task/661/fd’: Permissão negada
# find: ‘/proc/661/task/661/fdinfo’: Permissão negada
# find: ‘/proc/661/task/661/ns’: Permissão negada
# find: ‘/proc/661/fd’: Permissão negada
# find: ‘/proc/661/map_files’: Permissão negada
# find: ‘/proc/661/fdinfo’: Permissão negada
# find: ‘/proc/661/ns’: Permissão negada
# find: ‘/proc/735/task/735/fd’: Permissão negada
# find: ‘/proc/735/task/735/fdinfo’: Permissão negada
# find: ‘/proc/735/task/735/ns’: Permissão negada
# find: ‘/proc/735/fd’: Permissão negada
# find: ‘/proc/735/map_files’: Permissão negada
# find: ‘/proc/735/fdinfo’: Permissão negada
# find: ‘/proc/735/ns’: Permissão negada
# find: ‘/proc/741/task/741/fd’: Permissão negada
# find: ‘/proc/741/task/741/fdinfo’: Permissão negada
# find: ‘/proc/741/task/741/ns’: Permissão negada
# find: ‘/proc/741/fd’: Permissão negada
# find: ‘/proc/741/map_files’: Permissão negada
# find: ‘/proc/741/fdinfo’: Permissão negada
# find: ‘/proc/741/ns’: Permissão negada
# find: ‘/proc/835/task/835/fd’: Permissão negada
# find: ‘/proc/835/task/835/fdinfo’: Permissão negada
# find: ‘/proc/835/task/835/ns’: Permissão negada
# find: ‘/proc/835/task/836/fd’: Permissão negada
# find: ‘/proc/835/task/836/fdinfo’: Permissão negada
# find: ‘/proc/835/task/836/ns’: Permissão negada
# find: ‘/proc/835/task/837/fd’: Permissão negada
# find: ‘/proc/835/task/837/fdinfo’: Permissão negada
# find: ‘/proc/835/task/837/ns’: Permissão negada
# find: ‘/proc/835/fd’: Permissão negada
# find: ‘/proc/835/map_files’: Permissão negada
# find: ‘/proc/835/fdinfo’: Permissão negada
# find: ‘/proc/835/ns’: Permissão negada
# find: ‘/proc/872/task/872/fd’: Permissão negada
# find: ‘/proc/872/task/872/fdinfo’: Permissão negada
# find: ‘/proc/872/task/872/ns’: Permissão negada
# find: ‘/proc/872/task/880/fd’: Permissão negada
# find: ‘/proc/872/task/880/fdinfo’: Permissão negada
# find: ‘/proc/872/task/880/ns’: Permissão negada
# find: ‘/proc/872/task/883/fd’: Permissão negada
# find: ‘/proc/872/task/883/fdinfo’: Permissão negada
# find: ‘/proc/872/task/883/ns’: Permissão negada
# find: ‘/proc/872/task/884/fd’: Permissão negada
# find: ‘/proc/872/task/884/fdinfo’: Permissão negada
# find: ‘/proc/872/task/884/ns’: Permissão negada
# find: ‘/proc/872/task/885/fd’: Permissão negada
# find: ‘/proc/872/task/885/fdinfo’: Permissão negada
# find: ‘/proc/872/task/885/ns’: Permissão negada
# find: ‘/proc/872/fd’: Permissão negada
# find: ‘/proc/872/map_files’: Permissão negada
# find: ‘/proc/872/fdinfo’: Permissão negada
# find: ‘/proc/872/ns’: Permissão negada
# find: ‘/proc/913/task/913/fd’: Permissão negada
# find: ‘/proc/913/task/913/fdinfo’: Permissão negada
# find: ‘/proc/913/task/913/ns’: Permissão negada
# find: ‘/proc/913/task/925/fd’: Permissão negada
# find: ‘/proc/913/task/925/fdinfo’: Permissão negada
# find: ‘/proc/913/task/925/ns’: Permissão negada
# find: ‘/proc/913/task/930/fd’: Permissão negada
# find: ‘/proc/913/task/930/fdinfo’: Permissão negada
# find: ‘/proc/913/task/930/ns’: Permissão negada
# find: ‘/proc/913/task/934/fd’: Permissão negada
# find: ‘/proc/913/task/934/fdinfo’: Permissão negada
# find: ‘/proc/913/task/934/ns’: Permissão negada
# find: ‘/proc/913/task/979/fd’: Permissão negada
# find: ‘/proc/913/task/979/fdinfo’: Permissão negada
# find: ‘/proc/913/task/979/ns’: Permissão negada
# find: ‘/proc/913/fd’: Permissão negada
# find: ‘/proc/913/map_files’: Permissão negada
# find: ‘/proc/913/fdinfo’: Permissão negada
# find: ‘/proc/913/ns’: Permissão negada
# find: ‘/proc/918/task/918/fd’: Permissão negada
# find: ‘/proc/918/task/918/fdinfo’: Permissão negada
# find: ‘/proc/918/task/918/ns’: Permissão negada
# find: ‘/proc/918/task/922/fd’: Permissão negada
# find: ‘/proc/918/task/922/fdinfo’: Permissão negada
# find: ‘/proc/918/task/922/ns’: Permissão negada
# find: ‘/proc/918/task/923/fd’: Permissão negada
# find: ‘/proc/918/task/923/fdinfo’: Permissão negada
# find: ‘/proc/918/task/923/ns’: Permissão negada
# find: ‘/proc/918/fd’: Permissão negada
# find: ‘/proc/918/map_files’: Permissão negada
# find: ‘/proc/918/fdinfo’: Permissão negada
# find: ‘/proc/918/ns’: Permissão negada
# find: ‘/proc/1004/task/1004/fd’: Permissão negada
# find: ‘/proc/1004/task/1004/fdinfo’: Permissão negada
# find: ‘/proc/1004/task/1004/ns’: Permissão negada
# find: ‘/proc/1004/fd’: Permissão negada
# find: ‘/proc/1004/map_files’: Permissão negada
# find: ‘/proc/1004/fdinfo’: Permissão negada
# find: ‘/proc/1004/ns’: Permissão negada
# find: ‘/proc/1048/task/1048/fd’: Permissão negada
# find: ‘/proc/1048/task/1048/fdinfo’: Permissão negada
# find: ‘/proc/1048/task/1048/ns’: Permissão negada
# find: ‘/proc/1048/fd’: Permissão negada
# find: ‘/proc/1048/map_files’: Permissão negada
# find: ‘/proc/1048/fdinfo’: Permissão negada
# find: ‘/proc/1048/ns’: Permissão negada
# find: ‘/proc/3384/task/3384/fd’: Permissão negada
# find: ‘/proc/3384/task/3384/fdinfo’: Permissão negada
# find: ‘/proc/3384/task/3384/ns’: Permissão negada
# find: ‘/proc/3384/fd’: Permissão negada
# find: ‘/proc/3384/map_files’: Permissão negada
# find: ‘/proc/3384/fdinfo’: Permissão negada
# find: ‘/proc/3384/ns’: Permissão negada
# find: ‘/proc/3385/task/3385/fd’: Permissão negada
# find: ‘/proc/3385/task/3385/fdinfo’: Permissão negada
# find: ‘/proc/3385/task/3385/ns’: Permissão negada
# find: ‘/proc/3385/fd’: Permissão negada
# find: ‘/proc/3385/map_files’: Permissão negada
# find: ‘/proc/3385/fdinfo’: Permissão negada
# find: ‘/proc/3385/ns’: Permissão negada
# find: ‘/proc/3474/task/3474/fd’: Permissão negada
# find: ‘/proc/3474/task/3474/fdinfo’: Permissão negada
# find: ‘/proc/3474/task/3474/ns’: Permissão negada
# find: ‘/proc/3474/fd’: Permissão negada
# find: ‘/proc/3474/map_files’: Permissão negada
# find: ‘/proc/3474/fdinfo’: Permissão negada
# find: ‘/proc/3474/ns’: Permissão negada
# find: ‘/proc/4080/task/4080/fd’: Permissão negada
# find: ‘/proc/4080/task/4080/fdinfo’: Permissão negada
# find: ‘/proc/4080/task/4080/ns’: Permissão negada
# find: ‘/proc/4080/fd’: Permissão negada
# find: ‘/proc/4080/map_files’: Permissão negada
# find: ‘/proc/4080/fdinfo’: Permissão negada
# find: ‘/proc/4080/ns’: Permissão negada
# find: ‘/proc/4083/task/4083/fd’: Permissão negada
# find: ‘/proc/4083/task/4083/fdinfo’: Permissão negada
# find: ‘/proc/4083/task/4083/ns’: Permissão negada
# find: ‘/proc/4083/fd’: Permissão negada
# find: ‘/proc/4083/map_files’: Permissão negada
# find: ‘/proc/4083/fdinfo’: Permissão negada
# find: ‘/proc/4083/ns’: Permissão negada
# find: ‘/proc/4175/task/4175/fd’: Permissão negada
# find: ‘/proc/4175/task/4175/fdinfo’: Permissão negada
# find: ‘/proc/4175/task/4175/ns’: Permissão negada
# find: ‘/proc/4175/task/4181/fd’: Permissão negada
# find: ‘/proc/4175/task/4181/fdinfo’: Permissão negada
# find: ‘/proc/4175/task/4181/ns’: Permissão negada
# find: ‘/proc/4175/task/4183/fd’: Permissão negada
# find: ‘/proc/4175/task/4183/fdinfo’: Permissão negada
# find: ‘/proc/4175/task/4183/ns’: Permissão negada
# find: ‘/proc/4175/task/4191/fd’: Permissão negada
# find: ‘/proc/4175/task/4191/fdinfo’: Permissão negada
# find: ‘/proc/4175/task/4191/ns’: Permissão negada
# find: ‘/proc/4175/task/4196/fd’: Permissão negada
# find: ‘/proc/4175/task/4196/fdinfo’: Permissão negada
# find: ‘/proc/4175/task/4196/ns’: Permissão negada
# find: ‘/proc/4175/task/4197/fd’: Permissão negada
# find: ‘/proc/4175/task/4197/fdinfo’: Permissão negada
# find: ‘/proc/4175/task/4197/ns’: Permissão negada
# find: ‘/proc/4175/task/4198/fd’: Permissão negada
# find: ‘/proc/4175/task/4198/fdinfo’: Permissão negada
# find: ‘/proc/4175/task/4198/ns’: Permissão negada
# find: ‘/proc/4175/task/4199/fd’: Permissão negada
# find: ‘/proc/4175/task/4199/fdinfo’: Permissão negada
# find: ‘/proc/4175/task/4199/ns’: Permissão negada
# find: ‘/proc/4175/task/9462/fd’: Permissão negada
# find: ‘/proc/4175/task/9462/fdinfo’: Permissão negada
# find: ‘/proc/4175/task/9462/ns’: Permissão negada
# find: ‘/proc/4175/fd’: Permissão negada
# find: ‘/proc/4175/map_files’: Permissão negada
# find: ‘/proc/4175/fdinfo’: Permissão negada
# find: ‘/proc/4175/ns’: Permissão negada
# find: ‘/proc/4184/task/4184/fd’: Permissão negada
# find: ‘/proc/4184/task/4184/fdinfo’: Permissão negada
# find: ‘/proc/4184/task/4184/ns’: Permissão negada
# find: ‘/proc/4184/task/4187/fd’: Permissão negada
# find: ‘/proc/4184/task/4187/fdinfo’: Permissão negada
# find: ‘/proc/4184/task/4187/ns’: Permissão negada
# find: ‘/proc/4184/task/4189/fd’: Permissão negada
# find: ‘/proc/4184/task/4189/fdinfo’: Permissão negada
# find: ‘/proc/4184/task/4189/ns’: Permissão negada
# find: ‘/proc/4184/task/4204/fd’: Permissão negada
# find: ‘/proc/4184/task/4204/fdinfo’: Permissão negada
# find: ‘/proc/4184/task/4204/ns’: Permissão negada
# find: ‘/proc/4184/task/4208/fd’: Permissão negada
# find: ‘/proc/4184/task/4208/fdinfo’: Permissão negada
# find: ‘/proc/4184/task/4208/ns’: Permissão negada
# find: ‘/proc/4184/task/4212/fd’: Permissão negada
# find: ‘/proc/4184/task/4212/fdinfo’: Permissão negada
# find: ‘/proc/4184/task/4212/ns’: Permissão negada
# find: ‘/proc/4184/task/4213/fd’: Permissão negada
# find: ‘/proc/4184/task/4213/fdinfo’: Permissão negada
# find: ‘/proc/4184/task/4213/ns’: Permissão negada
# find: ‘/proc/4184/task/4215/fd’: Permissão negada
# find: ‘/proc/4184/task/4215/fdinfo’: Permissão negada
# find: ‘/proc/4184/task/4215/ns’: Permissão negada
# find: ‘/proc/4184/task/8612/fd’: Permissão negada
# find: ‘/proc/4184/task/8612/fdinfo’: Permissão negada
# find: ‘/proc/4184/task/8612/ns’: Permissão negada
# find: ‘/proc/4184/task/9475/fd’: Permissão negada
# find: ‘/proc/4184/task/9475/fdinfo’: Permissão negada
# find: ‘/proc/4184/task/9475/ns’: Permissão negada
# find: ‘/proc/4184/fd’: Permissão negada
# find: ‘/proc/4184/map_files’: Permissão negada
# find: ‘/proc/4184/fdinfo’: Permissão negada
# find: ‘/proc/4184/ns’: Permissão negada
# find: ‘/proc/4203/task/4203/fd’: Permissão negada
# find: ‘/proc/4203/task/4203/fdinfo’: Permissão negada
# find: ‘/proc/4203/task/4203/ns’: Permissão negada
# find: ‘/proc/4203/task/4209/fd’: Permissão negada
# find: ‘/proc/4203/task/4209/fdinfo’: Permissão negada
# find: ‘/proc/4203/task/4209/ns’: Permissão negada
# find: ‘/proc/4203/task/4211/fd’: Permissão negada
# find: ‘/proc/4203/task/4211/fdinfo’: Permissão negada
# find: ‘/proc/4203/task/4211/ns’: Permissão negada
# find: ‘/proc/4203/task/4217/fd’: Permissão negada
# find: ‘/proc/4203/task/4217/fdinfo’: Permissão negada
# find: ‘/proc/4203/task/4217/ns’: Permissão negada
# find: ‘/proc/4203/task/4218/fd’: Permissão negada
# find: ‘/proc/4203/task/4218/fdinfo’: Permissão negada
# find: ‘/proc/4203/task/4218/ns’: Permissão negada
# find: ‘/proc/4203/task/4220/fd’: Permissão negada
# find: ‘/proc/4203/task/4220/fdinfo’: Permissão negada
# find: ‘/proc/4203/task/4220/ns’: Permissão negada
# find: ‘/proc/4203/task/4221/fd’: Permissão negada
# find: ‘/proc/4203/task/4221/fdinfo’: Permissão negada
# find: ‘/proc/4203/task/4221/ns’: Permissão negada
# find: ‘/proc/4203/task/4222/fd’: Permissão negada
# find: ‘/proc/4203/task/4222/fdinfo’: Permissão negada
# find: ‘/proc/4203/task/4222/ns’: Permissão negada
# find: ‘/proc/4203/task/8609/fd’: Permissão negada
# find: ‘/proc/4203/task/8609/fdinfo’: Permissão negada
# find: ‘/proc/4203/task/8609/ns’: Permissão negada
# find: ‘/proc/4203/fd’: Permissão negada
# find: ‘/proc/4203/map_files’: Permissão negada
# find: ‘/proc/4203/fdinfo’: Permissão negada
# find: ‘/proc/4203/ns’: Permissão negada
# find: ‘/proc/4269/task/4269/fd’: Permissão negada
# find: ‘/proc/4269/task/4269/fdinfo’: Permissão negada
# find: ‘/proc/4269/task/4269/ns’: Permissão negada
# find: ‘/proc/4269/task/4272/fd’: Permissão negada
# find: ‘/proc/4269/task/4272/fdinfo’: Permissão negada
# find: ‘/proc/4269/task/4272/ns’: Permissão negada
# find: ‘/proc/4269/task/4274/fd’: Permissão negada
# find: ‘/proc/4269/task/4274/fdinfo’: Permissão negada
# find: ‘/proc/4269/task/4274/ns’: Permissão negada
# find: ‘/proc/4269/task/4275/fd’: Permissão negada
# find: ‘/proc/4269/task/4275/fdinfo’: Permissão negada
# find: ‘/proc/4269/task/4275/ns’: Permissão negada
# find: ‘/proc/4269/task/4276/fd’: Permissão negada
# find: ‘/proc/4269/task/4276/fdinfo’: Permissão negada
# find: ‘/proc/4269/task/4276/ns’: Permissão negada
# find: ‘/proc/4269/task/4278/fd’: Permissão negada
# find: ‘/proc/4269/task/4278/fdinfo’: Permissão negada
# find: ‘/proc/4269/task/4278/ns’: Permissão negada
# find: ‘/proc/4269/task/4279/fd’: Permissão negada
# find: ‘/proc/4269/task/4279/fdinfo’: Permissão negada
# find: ‘/proc/4269/task/4279/ns’: Permissão negada
# find: ‘/proc/4269/task/4280/fd’: Permissão negada
# find: ‘/proc/4269/task/4280/fdinfo’: Permissão negada
# find: ‘/proc/4269/task/4280/ns’: Permissão negada
# find: ‘/proc/4269/task/4366/fd’: Permissão negada
# find: ‘/proc/4269/task/4366/fdinfo’: Permissão negada
# find: ‘/proc/4269/task/4366/ns’: Permissão negada
# find: ‘/proc/4269/task/4374/fd’: Permissão negada
# find: ‘/proc/4269/task/4374/fdinfo’: Permissão negada
# find: ‘/proc/4269/task/4374/ns’: Permissão negada
# find: ‘/proc/4269/task/8309/fd’: Permissão negada
# find: ‘/proc/4269/task/8309/fdinfo’: Permissão negada
# find: ‘/proc/4269/task/8309/ns’: Permissão negada
# find: ‘/proc/4269/task/9089/fd’: Permissão negada
# find: ‘/proc/4269/task/9089/fdinfo’: Permissão negada
# find: ‘/proc/4269/task/9089/ns’: Permissão negada
# find: ‘/proc/4269/task/9542/fd’: Permissão negada
# find: ‘/proc/4269/task/9542/fdinfo’: Permissão negada
# find: ‘/proc/4269/task/9542/ns’: Permissão negada
# find: ‘/proc/4269/fd’: Permissão negada
# find: ‘/proc/4269/map_files’: Permissão negada
# find: ‘/proc/4269/fdinfo’: Permissão negada
# find: ‘/proc/4269/ns’: Permissão negada
# ...
# find: ‘/proc/5941/fdinfo’: Permissão negada
# find: ‘/proc/5941/ns’: Permissão negada
# find: ‘/proc/5978/task/5978/fd’: Permissão negada
# find: ‘/proc/5978/task/5978/fdinfo’: Permissão negada
# find: ‘/proc/5978/task/5978/ns’: Permissão negada
# find: ‘/proc/5978/task/5981/fd’: Permissão negada
# find: ‘/proc/5978/task/5981/fdinfo’: Permissão negada
# find: ‘/proc/5978/task/5981/ns’: Permissão negada
# find: ‘/proc/5978/task/5983/fd’: Permissão negada
# find: ‘/proc/5978/task/5983/fdinfo’: Permissão negada
# find: ‘/proc/5978/task/5983/ns’: Permissão negada
# find: ‘/proc/5978/task/5984/fd’: Permissão negada
# find: ‘/proc/5978/task/5984/fdinfo’: Permissão negada
# find: ‘/proc/5978/task/5984/ns’: Permissão negada
# find: ‘/proc/5978/task/5987/fd’: Permissão negada
# find: ‘/proc/5978/task/5987/fdinfo’: Permissão negada
# find: ‘/proc/5978/task/5987/ns’: Permissão negada
# find: ‘/proc/5978/task/5988/fd’: Permissão negada
# find: ‘/proc/5978/task/5988/fdinfo’: Permissão negada
# find: ‘/proc/5978/task/5988/ns’: Permissão negada
# find: ‘/proc/5978/task/5989/fd’: Permissão negada
# find: ‘/proc/5978/task/5989/fdinfo’: Permissão negada
# find: ‘/proc/5978/task/5989/ns’: Permissão negada
# find: ‘/proc/5978/task/5990/fd’: Permissão negada
# find: ‘/proc/5978/task/5990/fdinfo’: Permissão negada
# find: ‘/proc/5978/task/5990/ns’: Permissão negada
# find: ‘/proc/5978/task/7688/fd’: Permissão negada
# find: ‘/proc/5978/task/7688/fdinfo’: Permissão negada
# find: ‘/proc/5978/task/7688/ns’: Permissão negada
# find: ‘/proc/5978/fd’: Permissão negada
# find: ‘/proc/5978/map_files’: Permissão negada
# find: ‘/proc/5978/fdinfo’: Permissão negada
# find: ‘/proc/5978/ns’: Permissão negada
# find: ‘/proc/5986/task/5986/fd’: Permissão negada
# find: ‘/proc/5986/task/5986/fdinfo’: Permissão negada
# find: ‘/proc/5986/task/5986/ns’: Permissão negada
# find: ‘/proc/5986/task/5993/fd’: Permissão negada
# find: ‘/proc/5986/task/5993/fdinfo’: Permissão negada
# find: ‘/proc/5986/task/5993/ns’: Permissão negada
# find: ‘/proc/5986/task/5995/fd’: Permissão negada
# find: ‘/proc/5986/task/5995/fdinfo’: Permissão negada
# find: ‘/proc/5986/task/5995/ns’: Permissão negada
# find: ‘/proc/5986/task/5996/fd’: Permissão negada
# find: ‘/proc/5986/task/5996/fdinfo’: Permissão negada
# find: ‘/proc/5986/task/5996/ns’: Permissão negada
# find: ‘/proc/5986/task/5998/fd’: Permissão negada
# find: ‘/proc/5986/task/5998/fdinfo’: Permissão negada
# find: ‘/proc/5986/task/5998/ns’: Permissão negada
# find: ‘/proc/5986/task/5999/fd’: Permissão negada
# find: ‘/proc/5986/task/5999/fdinfo’: Permissão negada
# find: ‘/proc/5986/task/5999/ns’: Permissão negada
# find: ‘/proc/5986/task/6000/fd’: Permissão negada
# find: ‘/proc/5986/task/6000/fdinfo’: Permissão negada
# find: ‘/proc/5986/task/6000/ns’: Permissão negada
# find: ‘/proc/5986/task/6001/fd’: Permissão negada
# find: ‘/proc/5986/task/6001/fdinfo’: Permissão negada
# find: ‘/proc/5986/task/6001/ns’: Permissão negada
# find: ‘/proc/5986/task/6099/fd’: Permissão negada
# find: ‘/proc/5986/task/6099/fdinfo’: Permissão negada
# find: ‘/proc/5986/task/6099/ns’: Permissão negada
# find: ‘/proc/5986/task/6100/fd’: Permissão negada
# find: ‘/proc/5986/task/6100/fdinfo’: Permissão negada
# find: ‘/proc/5986/task/6100/ns’: Permissão negada
# find: ‘/proc/5986/task/8396/fd’: Permissão negada
# find: ‘/proc/5986/task/8396/fdinfo’: Permissão negada
# find: ‘/proc/5986/task/8396/ns’: Permissão negada
# find: ‘/proc/5986/task/9550/fd’: Permissão negada
# find: ‘/proc/5986/task/9550/fdinfo’: Permissão negada
# find: ‘/proc/5986/task/9550/ns’: Permissão negada
# find: ‘/proc/5986/fd’: Permissão negada
# find: ‘/proc/5986/map_files’: Permissão negada
# find: ‘/proc/5986/fdinfo’: Permissão negada
# find: ‘/proc/5986/ns’: Permissão negada
# find: ‘/proc/6522/task/6522/fd’: Permissão negada
# find: ‘/proc/6522/task/6522/fdinfo’: Permissão negada
# find: ‘/proc/6522/task/6522/ns’: Permissão negada
# find: ‘/proc/6522/task/6525/fd’: Permissão negada
# find: ‘/proc/6522/task/6525/fdinfo’: Permissão negada
# find: ‘/proc/6522/task/6525/ns’: Permissão negada
# find: ‘/proc/6522/task/6527/fd’: Permissão negada
# find: ‘/proc/6522/task/6527/fdinfo’: Permissão negada
# find: ‘/proc/6522/task/6527/ns’: Permissão negada
# find: ‘/proc/6522/task/6528/fd’: Permissão negada
# find: ‘/proc/6522/task/6528/fdinfo’: Permissão negada
# find: ‘/proc/6522/task/6528/ns’: Permissão negada
# find: ‘/proc/6522/task/6530/fd’: Permissão negada
# find: ‘/proc/6522/task/6530/fdinfo’: Permissão negada
# find: ‘/proc/6522/task/6530/ns’: Permissão negada
# find: ‘/proc/6522/task/6531/fd’: Permissão negada
# find: ‘/proc/6522/task/6531/fdinfo’: Permissão negada
# find: ‘/proc/6522/task/6531/ns’: Permissão negada
# find: ‘/proc/6522/task/6532/fd’: Permissão negada
# find: ‘/proc/6522/task/6532/fdinfo’: Permissão negada
# find: ‘/proc/6522/task/6532/ns’: Permissão negada
# find: ‘/proc/6522/task/6533/fd’: Permissão negada
# find: ‘/proc/6522/task/6533/fdinfo’: Permissão negada
# find: ‘/proc/6522/task/6533/ns’: Permissão negada
# find: ‘/proc/6522/task/6572/fd’: Permissão negada
# find: ‘/proc/6522/task/6572/fdinfo’: Permissão negada
# find: ‘/proc/6522/task/6572/ns’: Permissão negada
# find: ‘/proc/6522/task/9194/fd’: Permissão negada
# find: ‘/proc/6522/task/9194/fdinfo’: Permissão negada
# find: ‘/proc/6522/task/9194/ns’: Permissão negada
# find: ‘/proc/6522/fd’: Permissão negada
# find: ‘/proc/6522/map_files’: Permissão negada
# find: ‘/proc/6522/fdinfo’: Permissão negada
# find: ‘/proc/6522/ns’: Permissão negada
# find: ‘/proc/6534/task/6534/fd’: Permissão negada
# find: ‘/proc/6534/task/6534/fdinfo’: Permissão negada
# find: ‘/proc/6534/task/6534/ns’: Permissão negada
# find: ‘/proc/6534/task/6537/fd’: Permissão negada
# find: ‘/proc/6534/task/6537/fdinfo’: Permissão negada
# find: ‘/proc/6534/task/6537/ns’: Permissão negada
# find: ‘/proc/6534/task/6539/fd’: Permissão negada
# find: ‘/proc/6534/task/6539/fdinfo’: Permissão negada
# find: ‘/proc/6534/task/6539/ns’: Permissão negada
# find: ‘/proc/6534/task/6540/fd’: Permissão negada
# find: ‘/proc/6534/task/6540/fdinfo’: Permissão negada
# find: ‘/proc/6534/task/6540/ns’: Permissão negada
# find: ‘/proc/6534/task/6542/fd’: Permissão negada
# find: ‘/proc/6534/task/6542/fdinfo’: Permissão negada
# find: ‘/proc/6534/task/6542/ns’: Permissão negada
# find: ‘/proc/6534/task/6543/fd’: Permissão negada
# find: ‘/proc/6534/task/6543/fdinfo’: Permissão negada
# find: ‘/proc/6534/task/6543/ns’: Permissão negada
# find: ‘/proc/6534/task/6544/fd’: Permissão negada
# find: ‘/proc/6534/task/6544/fdinfo’: Permissão negada
# find: ‘/proc/6534/task/6544/ns’: Permissão negada
# find: ‘/proc/6534/task/6545/fd’: Permissão negada
# find: ‘/proc/6534/task/6545/fdinfo’: Permissão negada
# find: ‘/proc/6534/task/6545/ns’: Permissão negada
# find: ‘/proc/6534/task/8804/fd’: Permissão negada
# find: ‘/proc/6534/task/8804/fdinfo’: Permissão negada
# find: ‘/proc/6534/task/8804/ns’: Permissão negada
# find: ‘/proc/6534/fd’: Permissão negada
# find: ‘/proc/6534/map_files’: Permissão negada
# find: ‘/proc/6534/fdinfo’: Permissão negada
# find: ‘/proc/6534/ns’: Permissão negada
# find: ‘/proc/6550/task/6550/fd’: Permissão negada
# find: ‘/proc/6550/task/6550/fdinfo’: Permissão negada
# find: ‘/proc/6550/task/6550/ns’: Permissão negada
# find: ‘/proc/6550/task/6553/fd’: Permissão negada
# find: ‘/proc/6550/task/6553/fdinfo’: Permissão negada
# find: ‘/proc/6550/task/6553/ns’: Permissão negada
# find: ‘/proc/6550/task/6555/fd’: Permissão negada
# find: ‘/proc/6550/task/6555/fdinfo’: Permissão negada
# find: ‘/proc/6550/task/6555/ns’: Permissão negada
# find: ‘/proc/6550/task/6556/fd’: Permissão negada
# find: ‘/proc/6550/task/6556/fdinfo’: Permissão negada
# find: ‘/proc/6550/task/6556/ns’: Permissão negada
# find: ‘/proc/6550/task/6558/fd’: Permissão negada
# find: ‘/proc/6550/task/6558/fdinfo’: Permissão negada
# find: ‘/proc/6550/task/6558/ns’: Permissão negada
# find: ‘/proc/6550/task/6559/fd’: Permissão negada
# find: ‘/proc/6550/task/6559/fdinfo’: Permissão negada
# find: ‘/proc/6550/task/6559/ns’: Permissão negada
# find: ‘/proc/6550/task/6560/fd’: Permissão negada
# find: ‘/proc/6550/task/6560/fdinfo’: Permissão negada
# find: ‘/proc/6550/task/6560/ns’: Permissão negada
# find: ‘/proc/6550/task/6561/fd’: Permissão negada
# find: ‘/proc/6550/task/6561/fdinfo’: Permissão negada
# find: ‘/proc/6550/task/6561/ns’: Permissão negada
# find: ‘/proc/6550/task/9415/fd’: Permissão negada
# find: ‘/proc/6550/task/9415/fdinfo’: Permissão negada
# find: ‘/proc/6550/task/9415/ns’: Permissão negada
# find: ‘/proc/6550/fd’: Permissão negada
# find: ‘/proc/6550/map_files’: Permissão negada
# find: ‘/proc/6550/fdinfo’: Permissão negada
# find: ‘/proc/6550/ns’: Permissão negada
# find: ‘/proc/7476/task/7476/fd’: Permissão negada
# find: ‘/proc/7476/task/7476/fdinfo’: Permissão negada
# find: ‘/proc/7476/task/7476/ns’: Permissão negada
# find: ‘/proc/7476/fd’: Permissão negada
# find: ‘/proc/7476/map_files’: Permissão negada
# find: ‘/proc/7476/fdinfo’: Permissão negada
# find: ‘/proc/7476/ns’: Permissão negada
# find: ‘/proc/7559/task/7559/fd’: Permissão negada
# find: ‘/proc/7559/task/7559/fdinfo’: Permissão negada
# find: ‘/proc/7559/task/7559/ns’: Permissão negada
# find: ‘/proc/7559/fd’: Permissão negada
# find: ‘/proc/7559/map_files’: Permissão negada
# find: ‘/proc/7559/fdinfo’: Permissão negada
# find: ‘/proc/7559/ns’: Permissão negada
# find: ‘/proc/7821/task/7821/fd’: Permissão negada
# find: ‘/proc/7821/task/7821/fdinfo’: Permissão negada
# find: ‘/proc/7821/task/7821/ns’: Permissão negada
# find: ‘/proc/7821/fd’: Permissão negada
# find: ‘/proc/7821/map_files’: Permissão negada
# find: ‘/proc/7821/fdinfo’: Permissão negada
# find: ‘/proc/7821/ns’: Permissão negada
# find: ‘/proc/8362/task/8362/fd’: Permissão negada
# find: ‘/proc/8362/task/8362/fdinfo’: Permissão negada
# find: ‘/proc/8362/task/8362/ns’: Permissão negada
# find: ‘/proc/8362/fd’: Permissão negada
# find: ‘/proc/8362/map_files’: Permissão negada
# find: ‘/proc/8362/fdinfo’: Permissão negada
# find: ‘/proc/8362/ns’: Permissão negada
# find: ‘/proc/8792/task/8792/fd’: Permissão negada
# find: ‘/proc/8792/task/8792/fdinfo’: Permissão negada
# find: ‘/proc/8792/task/8792/ns’: Permissão negada
# find: ‘/proc/8792/fd’: Permissão negada
# find: ‘/proc/8792/map_files’: Permissão negada
# find: ‘/proc/8792/fdinfo’: Permissão negada
# find: ‘/proc/8792/ns’: Permissão negada
# find: ‘/proc/8810/task/8810/fd’: Permissão negada
# find: ‘/proc/8810/task/8810/fdinfo’: Permissão negada
# find: ‘/proc/8810/task/8810/ns’: Permissão negada
# find: ‘/proc/8810/fd’: Permissão negada
# find: ‘/proc/8810/map_files’: Permissão negada
# find: ‘/proc/8810/fdinfo’: Permissão negada
# find: ‘/proc/8810/ns’: Permissão negada
# find: ‘/proc/9333/task/9333/fd’: Permissão negada
# find: ‘/proc/9333/task/9333/fdinfo’: Permissão negada
# find: ‘/proc/9333/task/9333/ns’: Permissão negada
# find: ‘/proc/9333/task/9337/fd’: Permissão negada
# find: ‘/proc/9333/task/9337/fdinfo’: Permissão negada
# find: ‘/proc/9333/task/9337/ns’: Permissão negada
# find: ‘/proc/9333/task/9338/fd’: Permissão negada
# find: ‘/proc/9333/task/9338/fdinfo’: Permissão negada
# find: ‘/proc/9333/task/9338/ns’: Permissão negada
# find: ‘/proc/9333/task/9339/fd’: Permissão negada
# find: ‘/proc/9333/task/9339/fdinfo’: Permissão negada
# find: ‘/proc/9333/task/9339/ns’: Permissão negada
# find: ‘/proc/9333/task/9340/fd’: Permissão negada
# find: ‘/proc/9333/task/9340/fdinfo’: Permissão negada
# find: ‘/proc/9333/task/9340/ns’: Permissão negada
# find: ‘/proc/9333/task/9342/fd’: Permissão negada
# find: ‘/proc/9333/task/9342/fdinfo’: Permissão negada
# find: ‘/proc/9333/task/9342/ns’: Permissão negada
# find: ‘/proc/9333/task/9343/fd’: Permissão negada
# find: ‘/proc/9333/task/9343/fdinfo’: Permissão negada
# find: ‘/proc/9333/task/9343/ns’: Permissão negada
# find: ‘/proc/9333/task/9344/fd’: Permissão negada
# find: ‘/proc/9333/task/9344/fdinfo’: Permissão negada
# find: ‘/proc/9333/task/9344/ns’: Permissão negada
# find: ‘/proc/9333/task/9345/fd’: Permissão negada
# find: ‘/proc/9333/task/9345/fdinfo’: Permissão negada
# find: ‘/proc/9333/task/9345/ns’: Permissão negada
# find: ‘/proc/9333/task/9421/fd’: Permissão negada
# find: ‘/proc/9333/task/9421/fdinfo’: Permissão negada
# find: ‘/proc/9333/task/9421/ns’: Permissão negada
# find: ‘/proc/9333/task/9481/fd’: Permissão negada
# find: ‘/proc/9333/task/9481/fdinfo’: Permissão negada
# find: ‘/proc/9333/task/9481/ns’: Permissão negada
# find: ‘/proc/9333/task/9493/fd’: Permissão negada
# find: ‘/proc/9333/task/9493/fdinfo’: Permissão negada
# find: ‘/proc/9333/task/9493/ns’: Permissão negada
# find: ‘/proc/9333/fd’: Permissão negada
# find: ‘/proc/9333/map_files’: Permissão negada
# find: ‘/proc/9333/fdinfo’: Permissão negada
# find: ‘/proc/9333/ns’: Permissão negada
# find: ‘/proc/9348/task/9348/fd’: Permissão negada
# find: ‘/proc/9348/task/9348/fdinfo’: Permissão negada
# find: ‘/proc/9348/task/9348/ns’: Permissão negada
# find: ‘/proc/9348/fd’: Permissão negada
# find: ‘/proc/9348/map_files’: Permissão negada
# find: ‘/proc/9348/fdinfo’: Permissão negada
# find: ‘/proc/9348/ns’: Permissão negada
# find: ‘/proc/9352/task/9352/fd’: Permissão negada
# find: ‘/proc/9352/task/9352/fdinfo’: Permissão negada
# find: ‘/proc/9352/task/9352/ns’: Permissão negada
# find: ‘/proc/9352/task/9355/fd’: Permissão negada
# find: ‘/proc/9352/task/9355/fdinfo’: Permissão negada
# find: ‘/proc/9352/task/9355/ns’: Permissão negada
# find: ‘/proc/9352/task/9356/fd’: Permissão negada
# find: ‘/proc/9352/task/9356/fdinfo’: Permissão negada
# find: ‘/proc/9352/task/9356/ns’: Permissão negada
# find: ‘/proc/9352/task/9357/fd’: Permissão negada
# find: ‘/proc/9352/task/9357/fdinfo’: Permissão negada
# find: ‘/proc/9352/task/9357/ns’: Permissão negada
# find: ‘/proc/9352/task/9358/fd’: Permissão negada
# find: ‘/proc/9352/task/9358/fdinfo’: Permissão negada
# find: ‘/proc/9352/task/9358/ns’: Permissão negada
# find: ‘/proc/9352/task/9360/fd’: Permissão negada
# find: ‘/proc/9352/task/9360/fdinfo’: Permissão negada
# find: ‘/proc/9352/task/9360/ns’: Permissão negada
# find: ‘/proc/9352/task/9361/fd’: Permissão negada
# find: ‘/proc/9352/task/9361/fdinfo’: Permissão negada
# find: ‘/proc/9352/task/9361/ns’: Permissão negada
# find: ‘/proc/9352/task/9362/fd’: Permissão negada
# find: ‘/proc/9352/task/9362/fdinfo’: Permissão negada
# find: ‘/proc/9352/task/9362/ns’: Permissão negada
# find: ‘/proc/9352/task/9363/fd’: Permissão negada
# find: ‘/proc/9352/task/9363/fdinfo’: Permissão negada
# find: ‘/proc/9352/task/9363/ns’: Permissão negada
# find: ‘/proc/9352/fd’: Permissão negada
# find: ‘/proc/9352/map_files’: Permissão negada
# find: ‘/proc/9352/fdinfo’: Permissão negada
# find: ‘/proc/9352/ns’: Permissão negada
# find: ‘/proc/9524/task/9524/fd’: Permissão negada
# find: ‘/proc/9524/task/9524/fdinfo’: Permissão negada
# find: ‘/proc/9524/task/9524/ns’: Permissão negada
# find: ‘/proc/9524/fd’: Permissão negada
# find: ‘/proc/9524/map_files’: Permissão negada
# find: ‘/proc/9524/fdinfo’: Permissão negada
# find: ‘/proc/9524/ns’: Permissão negada
# find: ‘/tmp/systemd-private-ec1cd5dfadb249fc9b4b1bf46c033e07-upower.service-tuTeWD’: Permissão negada
# find: ‘/tmp/systemd-private-ec1cd5dfadb249fc9b4b1bf46c033e07-ModemManager.service-BtNGnl’: Permissão negada
# find: ‘/tmp/systemd-private-ec1cd5dfadb249fc9b4b1bf46c033e07-systemd-logind.service-PnQ4gI’: Permissão negada
# find: ‘/tmp/systemd-private-ec1cd5dfadb249fc9b4b1bf46c033e07-systemd-timesyncd.service-Ha5OE8’: Permissão negada
# find: ‘/lost+found’: Permissão negada
# find: ‘/etc/polkit-1/rules.d’: Permissão negada
# find: ‘/etc/cups/ssl’: Permissão negada
# find: ‘/etc/lvm/cache’: Permissão negada
# find: ‘/etc/NetworkManager/system-connections’: Permissão negada
# find: ‘/etc/pacman.d/gnupg/openpgp-revocs.d’: Permissão negada
# find: ‘/etc/pacman.d/gnupg/private-keys-v1.d’: Permissão negada
# find: ‘/etc/pacman.d/gnupg/crls.d’: Permissão negada
# find: ‘/etc/samba/private’: Permissão negada
# find: ‘/etc/audisp/plugins.d’: Permissão negada
# find: ‘/etc/sudoers.d’: Permissão negada
# find: ‘/usr/share/polkit-1/rules.d’: Permissão negada
# find: ‘/usr/lib/firmware/b43legacy’: Permissão negada
# find: ‘/usr/lib/firmware/b43’: Permissão negada
# find: ‘/sys/kernel/debug’: Permissão negada
# find: ‘/sys/fs/pstore’: Permissão negada
# find: ‘/sys/fs/bpf’: Permissão negada
# find: ‘/sys/fs/fuse/connections/8388641’: Permissão negada

# %%
import os
os.environ['NUMBAPRO_LIBDEVICE'] = "/usr/local/cuda-10.0/nvvm/libdevice"
os.environ['NUMBAPRO_NVVM'] = "/usr/local/cuda-10.0/nvvm/lib64/libnvvm.so"

# %%
import math
import numpy as np
from timeit import default_timer as timer
import numba as nb
from numba import jit, njit, prange, cuda

# %% [markdown]
# ### Informação sobre versão de Linux, CPU :

# %%
# !uname -a
# Out:
# Linux neuromancer 5.1.8-1-MANJARO #1 SMP PREEMPT Sun Jun 9 20:44:14 UTC 2019 x86_64 GNU/Linux

# %%
# !lsb_release -a
# Out:
# LSB Version:	n/a
# Distributor ID:	ManjaroLinux
# Description:	Manjaro Linux
# Release:	18.0.4
# Codename:	Illyria

# %%
# !lscpu
# Out:
# Arquitetura:                x86_64
# Modo(s) operacional da CPU: 32-bit, 64-bit
# Ordem dos bytes:            Little Endian
# Tamanhos de endereço:       39 bits physical, 48 bits virtual
# CPU(s):                     4
# Lista de CPU(s) on-line:    0-3
# Thread(s) per núcleo:       2
# Núcleo(s) por soquete:      2
# Soquete(s):                 1
# Nó(s) de NUMA:              1
# ID de fornecedor:           GenuineIntel
# Família da CPU:             6
# Modelo:                     142
# Nome do modelo:             Intel(R) Core(TM) i5-7200U CPU @ 2.50GHz
# Step:                       9
# CPU MHz:                    3100.216
# CPU MHz máx.:               3100,0000
# CPU MHz mín.:               400,0000
# BogoMIPS:                   5426.00
# Virtualização:              VT-x
# cache de L1d:               32K
# cache de L1i:               32K
# cache de L2:                256K
# cache de L3:                3072K
# CPU(s) de nó0 NUMA:         0-3
# Opções:                     fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm constant_tsc art arch_perfmon pebs bts rep_good nopl xtopology nonstop_tsc cpuid aperfmperf tsc_known_freq pni pclmulqdq dtes64 monitor ds_cpl vmx est tm2 ssse3 sdbg fma cx16 xtpr pdcm pcid sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave avx f16c rdrand lahf_lm abm 3dnowprefetch cpuid_fault invpcid_single pti ssbd ibrs ibpb stibp tpr_shadow vnmi flexpriority ept vpid ept_ad fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid mpx rdseed adx smap clflushopt intel_pt xsaveopt xsavec xgetbv1 xsaves dtherm ida arat pln pts hwp hwp_notify hwp_act_window hwp_epp md_clear flush_l1d

# %% [markdown]
# Versão de Numba :

# %%
nb.__version__
# Out:
# '0.43.1'

# %%
nb.config.NUMBA_DEFAULT_NUM_THREADS
# Out:
# 4

# %% [markdown]
# Versão de gcc :

# %%
# !gcc --version
# Out:
# gcc (GCC) 8.3.0
# Copyright (C) 2018 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %% [markdown]
# Versão de Python :

# %%
# !python --version
# Out:
# Python 3.7.3

# %% [markdown]
# Versão de NumPy :

# %%
np.__version__
# Out:
# '1.16.2'

# %% [markdown]
# ## Definições de nbody para Python puro, NumPy, Numba CPU e Numba CPU //

# %%
G = 6.67408*1e-11 # define a constante gravitacional
sft = 1e-10 # define a constante de atenuamento para tratamento das singularidades

# %%
@njit
def gravitationalNbody_NumbaCPU(r, v, a, m, nobj, ninter, dt, flag_Energy=False):
    for inter in range(ninter):
        for i in range(nobj):
            a[i][0] = 0.0; a[i][1] = 0.0; a[i][2] = 0.0
            for j in range(nobj):
                if i != j:
                    # calculate a_ij acceleration
                    dx = r[j][0] - r[i][0]; dy = r[j][1] - r[i][1]; dz = r[j][2] - r[i][2]
                    dsq = dx*dx + dy*dy + dz*dz + sft*sft
                    gA = (G*m[j])/(dsq*math.sqrt(dsq))
                    # sum a_ij_x to a_i_x, etc
                    a[i][0] += gA*dx; a[i][1] += gA*dy; a[i][2] += gA*dz
            # update the v_i velocity
            v[i][0] += a[i][0]*dt; v[i][1] += a[i][1]*dt; v[i][2] += a[i][2]*dt
        for i in range(nobj):
            # update the r_i position
            r[i][0] += v[i][0]*dt; r[i][1] += v[i][1]*dt; r[i][2] += v[i][2]*dt
    K = 0.0; U = 0.0
    if flag_Energy:
        for i in range(nobj):
            # Sum the total kinectic energy
            K += 0.5*m[i]*(v[i][0]**2 + v[i][1]**2 + v[i][2]**2)
            for j in range(nobj):
                if (i < j):
                    # Sum the total potential energy
                    U += (-G*m[i]*m[j])/math.sqrt((r[j][0] - r[i][0])**2 + (r[j][1] - r[i][1])**2 + 
                                                  (r[j][2] - r[i][2])**2 + sft**2)
    return K, U

# %%
@njit(parallel=True)
def gravitationalNbody_NumbaCPUparallel(r, v, a, m, nobj, ninter, dt, flag_Energy=False):
    for inter in range(ninter):
        for i in prange(nobj):
            a[i][0] = 0.0; a[i][1] = 0.0; a[i][2] = 0.0
            for j in range(nobj):
                if i != j:
                    # calculate a_ij acceleration
                    dx = r[j][0] - r[i][0]; dy = r[j][1] - r[i][1]; dz = r[j][2] - r[i][2]
                    dsq = dx*dx + dy*dy + dz*dz + sft*sft
                    gA = (G*m[j])/(dsq*math.sqrt(dsq))
                    # sum a_ij_x to a_i_x, etc
                    a[i][0] += gA*dx; a[i][1] += gA*dy; a[i][2] += gA*dz
            # update the v_i velocity
            v[i][0] += a[i][0]*dt; v[i][1] += a[i][1]*dt; v[i][2] += a[i][2]*dt
        for i in prange(nobj):
            # update the r_i position
            r[i][0] += v[i][0]*dt; r[i][1] += v[i][1]*dt; r[i][2] += v[i][2]*dt
    K = 0.0; U = 0.0
    if flag_Energy:
        for i in prange(nobj):
            # Sum the total kinectic energy
            K += 0.5*m[i]*(v[i][0]**2 + v[i][1]**2 + v[i][2]**2)
            for j in range(nobj):
                if (i < j):
                    # Sum the total potential energy
                    U += (-G*m[i]*m[j])/math.sqrt((r[j][0] - r[i][0])**2 + (r[j][1] - r[i][1])**2 + 
                                                  (r[j][2] - r[i][2])**2 + sft**2)
    return K, U

# %%
@njit
def gravitationalNbody_NumPy_NumbaCPU(r, v, a, m, nobj, ninter, dt, flag_Energy=False):
    for inter in range(ninter):
        # zero the a acceleration
        a = np.zeros((nobj, 3))
        for i in range(nobj):
            # update the a acceleration
            dr = r[i] - r
            dsq = np.sum(dr*dr, axis=1) + sft*sft
            gA = (G*m[i])/(dsq*np.sqrt(dsq))
            a += (dr.T*gA).T
        # update the v velocity
        v += a*dt
        # update the r position
        r += v*dt
    K = 0.0; U = 0.0
    if flag_Energy:
        # Sum the total kinetic energy
        K = np.sum(0.5*m*np.sum(v*v, axis=1))
        U = 0.0
        for i in range(nobj):
            for j in range(nobj):
                if (i < j):
                    # Sum the total potential energy
                    U += (-G*m[i]*m[j])/math.sqrt((r[j][0] - r[i][0])**2 + (r[j][1] - r[i][1])**2 + 
                                                  (r[j][2] - r[i][2])**2 + sft**2)
    return K, U

# %%
@njit(parallel=True)
def gravitationalNbody_NumPy_NumbaCPUparallel(r, v, a, m, nobj, ninter, dt, flag_Energy=False):
    for inter in range(ninter):
        # zero the a acceleration
        a = np.zeros((nobj, 3))
        for i in prange(nobj):
            # update the a acceleration
            dr = r[i] - r
            dsq = np.sum(dr*dr, axis=1) + sft*sft
            gA = (G*m[i])/(dsq*np.sqrt(dsq))
            a += (dr.T*gA).T
        # update the v velocity
        v += a*dt
        # update the r position
        r += v*dt
    K = 0.0; U = 0.0
    if flag_Energy:
        K = np.sum(0.5*m*np.sum(v*v, axis=1))
        U = 0.0
        for i in prange(nobj):
            for j in range(nobj):
                if (i < j):
                    # Sum the total potential energy
                    U += (-G*m[i]*m[j])/math.sqrt((r[j][0] - r[i][0])**2 + (r[j][1] - r[i][1])**2 + 
                                                  (r[j][2] - r[i][2])**2 + sft**2)
    return K, U

# %%
# n_cube_edge : número de pontos l de cada aresta de um cubo
# ninter : M, número de interações
# dt : dt, intervalo entre interações
def run_nbody(gravitationalNbodyfunction, n_cube_edge=10, ninter = 5, dt = 0.01, 
              flag_array=True, flag_compile=True, flag_Energy= False, flag_verbose=False):
    nbody_version = "1.6.3"

    nobj = n_cube_edge**3 # define o número de objetos na simulação
    if flag_array:
        positions = np.zeros((nobj, 3))   # inicializa uma lista de N posições 3D, nulas inicialmente
        velocities = np.zeros_like(positions)   # inicializa uma lista de N velocidades 3D, nulas inicialmente
        accelerations = np.zeros_like(positions)   # inicializa uma lista de N acelerações 3D, nulas inicialmente
        masses = 1e9*np.ones(nobj)   # inicializa uma lista de N massas, aqui iguais a 10^6 kg
    else:
        positions = [[0., 0., 0.] for i in range(nobj)]   # inicializa uma lista de N de objetos para posição e massa, nulas inicialmente
        velocities = [[0., 0., 0.] for i in range(nobj)]   # inicializa uma lista de N velocidades 3D, nulas inicialmente
        accelerations = [[0., 0., 0.] for i in range(nobj)]   # inicializa uma lista de N acelerações 3D, nulas inicialmente
        masses = [1e9]*nobj   # inicializa uma lista de N massas, aqui iguais a 10^6 kg
    # Cria um cubo de l^3 pontos, onde cada aresta tem l pontos   
    scale = 1.0  # escala do cubo, com comprimento da aresta = scale*n_cube_edge
    n_half_cube_edge = int(n_cube_edge/2)
    for i in range(n_cube_edge):
        for j in range(n_cube_edge):
            for k in range(n_cube_edge):
                positions[k + j*n_cube_edge + i*n_cube_edge*n_cube_edge] = [(i - n_half_cube_edge)*scale, 
                                                                            (j - n_half_cube_edge)*scale,
                                                                            (k - n_half_cube_edge)*scale]                
    if flag_compile:
        # To Numba compile the function 1st time before calling with full data
        positions_backup = positions.copy()
        velocities_backup = velocities.copy()
        accelerations_backup = accelerations.copy()
        print("N-Body (C) Flavio Manoel, v{}".format(nbody_version))
        print("N = {} corpos, dt = {}s, M = {} interações".format(nobj, dt, ninter))
        start = timer()
        Kf, Uf = gravitationalNbodyfunction(positions, velocities, accelerations, masses, nobj, ninter, dt, 
                                            flag_Energy=flag_Energy)
        end = timer()
        if flag_Energy:
            print("Após {} passos, {:.4f}s, Ef = {}, Kf = {}, Uf = {}".format(ninter, ninter*dt, 
                                                                                          Kf + Uf, Kf, Uf))
        dt_compile_run = end - start
        print("Código executado em {:.6f} s\n".format(dt_compile_run))
        positions = positions_backup.copy()
        velocities = velocities_backup.copy()
        accelerations = accelerations_backup.copy()
    else:
        dt_compile_run = 0.0
        
    print("N-Body (C) Flavio Manoel, v{}".format(nbody_version))
    print("N = {} corpos, dt = {}s, M = {} interações".format(nobj, dt, ninter))
    if flag_verbose:
        print("Posições = {}\nVelocidades = {}\nAcelerações = {}\nMassas = {}\n".format(positions, 
              velocities, accelerations, masses))
    start = timer()
    if flag_Energy:
        Ki, Ui = gravitationalNbodyfunction(positions, velocities, accelerations, masses, nobj, 0, dt, 
                                            flag_Energy=flag_Energy)
        print("Ei = {}, Ki = {}, Ui = {}".format(Ki + Ui, Ki, Ui))
    Kf, Uf = gravitationalNbodyfunction(positions, velocities, accelerations, masses, nobj, ninter, dt, 
                                        flag_Energy=flag_Energy)
    end = timer()
    if flag_Energy:
        erro_perc = 100.0*(Kf + Uf - (Ki + Ui))/(Ki + Ui)
        print("Após {} passos, {:.4f}s :\nEf = {}, Kf = {}, Uf = {}, erro em E = {}%".format(ninter, 
               ninter*dt, Kf + Uf, Kf, Uf, erro_perc))
    else:
        erro_perc = 0.0
    dt_run = end - start
    print("Código executado em {:.6f} s".format(dt_run))
    if flag_verbose:
        print("\nPositions = {}\nVelocities = {}\nAccelerations = {}".format(positions, velocities, 
                                                                             accelerations))
    return dt_compile_run, dt_run, erro_perc

# %% [markdown]
# ## Testes de nbody

# %%
n_cube_edge=32; ninter = 1; dt = 0.01

# %% [markdown]
# ### Teste de nbody em Python puro

# %%
#t_all_py, t_py, erro_py = run_nbody(gravitationalNbody_NumbaCPU.py_func, n_cube_edge=n_cube_edge, ninter=ninter, 
#                                    dt=dt, flag_array=False, flag_Energy=True, flag_compile=False)

# %%
t_all_py, t_py, erro_py = run_nbody(gravitationalNbody_NumbaCPU.py_func, n_cube_edge=n_cube_edge, ninter=ninter, 
                                    dt=dt, flag_array=False, flag_compile=False)
# Out:
# N-Body (C) Flavio Manoel, v1.6.3
# N = 32768 corpos, dt = 0.01s, M = 1 interações
# Código executado em 936.494317 s

# %% [markdown]
# ### Teste de nbody em Python (com NumPy arrays)

# %%
#t_all_py_a, t_py_a, erro_py_a = run_nbody(gravitationalNbody_NumbaCPU.py_func, n_cube_edge=n_cube_edge, 
#                                          ninter=ninter, dt=dt, flag_Energy=True, flag_compile=False)

# %%
#t_all_py_a, t_py_a, erro_py_a = run_nbody(gravitationalNbody_NumbaCPU.py_func, n_cube_edge=n_cube_edge, 
#                                          ninter=ninter, dt=dt, flag_compile=False)

# %% [markdown]
# ### Teste de nbody em Python NumPy

# %%
#t_all_np, t_np, erro_np = run_nbody(gravitationalNbody_NumPy_NumbaCPU.py_func, n_cube_edge=n_cube_edge, 
#                                    ninter=ninter, dt=dt, flag_Energy=True, flag_compile=False)

# %%
t_all_np, t_np, erro_np = run_nbody(gravitationalNbody_NumPy_NumbaCPU.py_func, n_cube_edge=n_cube_edge, 
                                    ninter=ninter, dt=dt, flag_compile=False)
# Out:
# N-Body (C) Flavio Manoel, v1.6.3
# N = 32768 corpos, dt = 0.01s, M = 1 interações
# Código executado em 56.494941 s

# %% [markdown]
# ### Teste de nbody em Python Numba CPU

# %%
#t_all_nb, t_nb, erro_nb = run_nbody(gravitationalNbody_NumbaCPU, n_cube_edge=n_cube_edge, ninter=ninter, 
#                                    dt=dt, flag_Energy=True)

# %%
t_all_nb, t_nb, erro_nb = run_nbody(gravitationalNbody_NumbaCPU, n_cube_edge=n_cube_edge, ninter=ninter, 
                                    dt=dt)
# Out:
# N-Body (C) Flavio Manoel, v1.6.3
# N = 32768 corpos, dt = 0.01s, M = 1 interações
# Código executado em 8.947222 s
#
# N-Body (C) Flavio Manoel, v1.6.3
# N = 32768 corpos, dt = 0.01s, M = 1 interações
# Código executado em 7.216753 s

# %% [markdown]
# ### Teste de nbody em NumPy Numba CPU

# %%
#t_all_np_nb, t_np_nb, erro_np_nb = run_nbody(gravitationalNbody_NumPy_NumbaCPU, n_cube_edge=n_cube_edge, 
#                                             ninter=ninter, dt=dt, flag_Energy=True)

# %%
t_all_np_nb, t_np_nb, erro_np_nb = run_nbody(gravitationalNbody_NumPy_NumbaCPU, n_cube_edge=n_cube_edge, 
                                             ninter=ninter, dt=dt)
# Out:
# N-Body (C) Flavio Manoel, v1.6.3
# N = 32768 corpos, dt = 0.01s, M = 1 interações
# Código executado em 29.616228 s
#
# N-Body (C) Flavio Manoel, v1.6.3
# N = 32768 corpos, dt = 0.01s, M = 1 interações
# Código executado em 23.509821 s

# %% [markdown]
# ### Teste de nbody em Python Numba CPU //

# %%
#t_all_nb_parallel, t_nb_parallel, erro_nb_parallel = run_nbody(gravitationalNbody_NumbaCPUparallel, 
#                                             n_cube_edge=n_cube_edge, ninter=ninter, dt=dt, flag_Energy=True)

# %%
t_all_nb_parallel, t_nb_parallel, erro_nb_parallel = run_nbody(gravitationalNbody_NumbaCPUparallel, 
                                                               n_cube_edge=n_cube_edge, ninter=ninter, dt=dt)
# Out:
# N-Body (C) Flavio Manoel, v1.6.3
# N = 32768 corpos, dt = 0.01s, M = 1 interações
# Código executado em 6.071021 s
#
# N-Body (C) Flavio Manoel, v1.6.3
# N = 32768 corpos, dt = 0.01s, M = 1 interações
# Código executado em 2.906432 s

# %% [markdown]
# ### Teste de nbody em NumPy Numba CPU //

# %%
#t_all_np_nb_parallel, t_np_nb_parallel, erro_np_nb_parallel = run_nbody(
#    gravitationalNbody_NumPy_NumbaCPUparallel, n_cube_edge=n_cube_edge, ninter=ninter, dt=dt, flag_Energy=True)

# %%
t_all_np_nb_parallel, t_np_nb_parallel, erro_np_nb_parallel = run_nbody(
                    gravitationalNbody_NumPy_NumbaCPUparallel, n_cube_edge=n_cube_edge, ninter=ninter, dt=dt)
# Out:
# N-Body (C) Flavio Manoel, v1.6.3
# N = 32768 corpos, dt = 0.01s, M = 1 interações
# Código executado em 30.422976 s
#
# N-Body (C) Flavio Manoel, v1.6.3
# N = 32768 corpos, dt = 0.01s, M = 1 interações
# Código executado em 21.879411 s

# %% [markdown]
# ### Teste de nbody em Python Numba GPU 64 bits (double precision)

# %%
#t_all_gpu, t_gpu, erro_gpu = run_nbody(gravitationalNbody_NumbaGPU64, n_cube_edge=n_cube_edge, 
#                                       ninter=ninter, dt=dt, flag_Energy=True)

# %%
#t_all_gpu, t_gpu, erro_gpu = run_nbody(gravitationalNbody_NumbaGPU64, n_cube_edge=n_cube_edge, 
#                                       ninter=ninter, dt=dt)

# %% [markdown]
# ### Resultados e comparações

# %% [markdown]
# Speed up of pure Python with respect to Python (with NumPy arrays)  :

# %%
#t_py_a / t_py

# %% [markdown]
# Speed up of Python NumPy with respect to pure Python :

# %%
t_py / t_np
# Out:
# 16.57660504296176

# %% [markdown]
# Speed up of Python Numba CPU (serial) with respect to pure Python :

# %%
t_py / t_nb
# Out:
# 129.76670948531296

# %% [markdown]
# Speed up of Python Numba CPU (serial) with respect to Python (with NumPy arrays) :

# %%
#t_py_a / t_nb

# %% [markdown]
# Speed up of Python Numba CPU (serial) with respect to Python NumPy :

# %%
t_np / t_nb
# Out:
# 7.828304357194686

# %% [markdown]
# Speed up of NumPy Numba CPU (serial) with respect to pure Python :

# %%
t_py / t_np_nb
# Out:
# 39.83417553068706

# %% [markdown]
# Speed up of NumPy Numba CPU (serial) with respect to Python NumPy :

# %%
t_np / t_np_nb
# Out:
# 2.403035810254779

# %% [markdown]
# Speed up of Python Numba CPU // with respect to pure Python :

# %%
t_py / t_nb_parallel
# Out:
# 322.21439839294663

# %% [markdown]
# Speed up of Python Numba CPU // with respect to Python (with NumPy arrays) :

# %%
#t_py_a / t_nb_parallel

# %% [markdown]
# Speed up of NumPy Numba CPU // with respect to Python NumPy :

# %%
t_np / t_np_nb_parallel
# Out:
# 2.582105172386834

# %% [markdown]
# Speed up of Python Numba CPU // with respect to Python Numba CPU :

# %%
t_nb / t_nb_parallel
# Out:
# 2.48302819475757

# %% [markdown]
# Speed up of NumPy Numba CPU // with respect to NumPy Numba CPU :

# %%
t_np_nb / t_np_nb_parallel
# Out:
# 1.0745179748749019

# %% [markdown]
# Speed up of Python Numba GPU 64 bits with respect to pure Python :

# %%
t_py / t_gpu
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-0519caad41ee> in <module>
# ----> 1 t_py / t_gpu
#
# NameError: name 't_gpu' is not defined

# %% [markdown]
# Speed up of Python Numba GPU 64 bits with respect to Python (with NumPy arrays) :

# %%
#t_py_a / t_gpu

# %% [markdown]
# Speed up of NumPy Numba GPU 64 bits  with respect to Python NumPy :

# %%
#t_np / t_gpu

# %% [markdown]
# Speed up of Python Numba GPU 64 bits  with respect to Python Numba CPU (serial) :

# %%
#t_nb / t_gpu

# %% [markdown]
# Speed up of NumPy Numba GPU 64 bits with respect to Python Numba CPU // :

# %%
#t_nb_parallel / t_gpu
